# %% [markdown]
# <a href="https://colab.research.google.com/github/duyanh78/O-RDC-Algorithm/blob/main/WQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import random
from google.colab import drive
import os
import logging
from geopy.distance import geodesic

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Connect to Google Drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive

# %%
import random

class CacheEntry:
    def __init__(self, request, remaining_time, state="initialized"):
        self.request = request
        self.remaining_time = remaining_time
        self.state = state

class EdgeNode:
    def __init__(self, site_id, latitude, longitude, name, cpu_frequency, hardware_capacity):
        self.site_id = site_id
        self.latitude = latitude
        self.longitude = longitude
        self.name = name
        self.cpu_frequency = cpu_frequency
        self.hardware_capacity = hardware_capacity
        self.available_ram = hardware_capacity  # Initialize available RAM as total hardware capacity
        self.cache = {t: [] for t in range(100)}  # Initialize cache with 50 empty lists
        self.request_counter = 0  # Counter to assign unique IDs to requests
        self.queue = {t: [] for t in range(100)}

    def __repr__(self):
        return f"{self.site_id}-{self.name}: ({self.latitude}, {self.longitude}), CPU: {self.cpu_frequency} GHz, Capacity: {self.hardware_capacity} MB, Available RAM: {self.available_ram} MB"

    def can_store_container(self, container_size):
        return self.available_ram >= container_size

    def store_request(self, request, remaining_time, current_time_slot):
        self.request_counter += 1  # Increment the counter for each new request
        unique_request_id = self.request_counter  # Assign the counter value as the unique ID
        unique_request = Request(unique_request_id, request.request_type, request.size, request.timestamp)
        if self.can_store_container(request.size):
            self.available_ram -= request.size  # Decrease available RAM
            if self.cache[current_time_slot] is None:
                self.cache[current_time_slot] = []
            self.cache[current_time_slot].append(CacheEntry(unique_request, remaining_time, state="initialized"))
            return True
        return False

    def update_cache(self, current_time_slot):
        new_cache = []
        previous_time_slot = current_time_slot - 1
        if previous_time_slot in self.cache and self.cache[previous_time_slot] is not None:
            # Tạo bản sao của các entry trước khi cập nhật remaining_time
            current_entries = [CacheEntry(entry.request, entry.remaining_time, entry.state) for entry in self.cache[previous_time_slot]]
            self.cache[current_time_slot] = current_entries
            for entry in current_entries:
                entry.remaining_time -= 1
                if entry.remaining_time <= 0:  # Nếu container hết thời gian remaining_time
                    self.remove_container(entry, current_time_slot)
                else:
                    if entry.state == "served":
                        entry.state = "stored"  # Chuyển trạng thái sang lưu trữ trong time-slot tiếp theo
                    if entry.state == "initialized":
                        entry.state = "stored"
                    new_cache.append(entry)
        self.cache[current_time_slot] = new_cache if new_cache else None
        return 0

    def pop_container(self, current_time_slot):
        if self.cache[current_time_slot]:
            entry = self.cache[current_time_slot].pop(0)
            self.available_ram += entry.request.size
            if self.available_ram > self.hardware_capacity:
                self.available_ram = self.hardware_capacity  # Ensure available_ram does not exceed hardware_capacity
            return entry
        return None

    def calculate_a_n_k_t(self, current_time_slot):
        count = {k: {t: 0 for t in range(100)} for k in range(1, 51)}
        if current_time_slot in self.cache:
            if self.cache[current_time_slot] is None:
                for k in range(1, 51):
                    count[k][current_time_slot] = 0
            else:
                for entry in self.cache[current_time_slot]:
                    if entry.remaining_time > 0 and entry.state == "stored" :  # Chỉ tính các container ở trạng thái lưu trữ
                        count[entry.request.request_type][current_time_slot] += 1
        return count

    def remove_container(self, entry, current_time_slot):
        self.available_ram += entry.request.size
        if self.available_ram > self.hardware_capacity:
            self.available_ram = self.hardware_capacity  # Ensure available_ram does not exceed hardware_capacity
        if self.cache[current_time_slot] is not None:
            self.cache[current_time_slot] = [e for e in self.cache[current_time_slot] if e != entry]

    def update_container(self, entry, new_remaining_time, current_time_slot):
        entry.remaining_time = new_remaining_time
        entry.state = "served"  # Chuyển trạng thái sang đã phục vụ sau khi phục vụ
        # Lưu lại entry vào cache
        self.remove_container(entry, current_time_slot)
        if self.cache[current_time_slot] is None:
            self.cache[current_time_slot] = []
        self.cache[current_time_slot].append(entry)


from geopy.distance import geodesic

class Zone:
    def __init__(self, zone_id, nodes):
        self.zone_id = zone_id
        self.nodes = nodes
        self.instantiation_costs = {}
        self.retention_costs = {}

    def calculate_costs(self, ranked_functions):
        for node in self.nodes:
            for k, (hash_function, invocations, size) in ranked_functions.items():
                dnk = size / node.cpu_frequency  # Instantiation cost
                rnk = size * node.cpu_frequency  # Retention cost
                self.instantiation_costs[(node.site_id, k)] = dnk
                self.retention_costs[(node.site_id, k)] = rnk

    def get_zone_center(self):
        latitudes = [node.latitude for node in self.nodes]
        longitudes = [node.longitude for node in self.nodes]
        center_latitude = sum(latitudes) / len(latitudes)
        center_longitude = sum(longitudes) / len(longitudes)
        return (center_latitude, center_longitude)


def calculate_communication_cost(zones, K):
    communication_costs = {}

    for zone_id_1, zone_1 in zones.items():
        for zone_id_2, zone_2 in zones.items():
            if zone_id_1 != zone_id_2:
                # Calculate geographical distance between zone centers
                center_1 = zone_1.get_zone_center()
                center_2 = zone_2.get_zone_center()
                distance = geodesic(center_1, center_2).kilometers

                for k in range(1, K + 1):
                    # Calculate minimal and maximal instantiation costs for container type k in both zones
                    min_inst_cost_1 = min(zone_1.instantiation_costs[(node.site_id, k)] for node in zone_1.nodes)
                    max_inst_cost_1 = max(zone_1.instantiation_costs[(node.site_id, k)] for node in zone_1.nodes)
                    min_inst_cost_2 = min(zone_2.instantiation_costs[(node.site_id, k)] for node in zone_2.nodes)
                    max_inst_cost_2 = max(zone_2.instantiation_costs[(node.site_id, k)] for node in zone_2.nodes)

                    # Communication cost for container type k is the average of minimal and maximal instantiation costs plus distance
                    comm_cost = (min_inst_cost_1 + max_inst_cost_1 + min_inst_cost_2 + max_inst_cost_2) / 4
                    comm_cost += distance  # Add distance to communication cost

                    communication_costs[(zone_id_1, zone_id_2, k)] = comm_cost

    return communication_costs

# %%
def load_edge_nodes(file_path, zone_node_ids):
    cpu_frequencies = [2.4, 2.7, 3.0, 3.3, 3.6]
    hardware_capacities = np.arange(16000, 24000, 1000)

    df = pd.read_csv(file_path)
    edge_nodes = []

    for zone_id, node_ids in zone_node_ids.items():
        assigned_frequencies = []
        zone_nodes = []
        for index, node_id in enumerate(node_ids):
            row = df[df['SITE_ID'] == node_id].iloc[0]
            if len(assigned_frequencies) < 5:
                cpu_frequency = cpu_frequencies[len(assigned_frequencies)]
                assigned_frequencies.append(cpu_frequency)
            else:
                cpu_frequency = random.choice(cpu_frequencies)
            edge_node = EdgeNode(row.SITE_ID, row.LATITUDE, row.LONGITUDE, row.NAME, cpu_frequency, random.choice(hardware_capacities))
            zone_nodes.append(edge_node)

        # Ensure each zone has all 5 cpu frequencies
        missing_frequencies = set(cpu_frequencies) - set(assigned_frequencies)
        if missing_frequencies:
            for missing_freq in missing_frequencies:
                index = random.choice(range(len(zone_nodes)))
                zone_nodes[index].cpu_frequency = missing_freq

        edge_nodes.extend(zone_nodes)

    return edge_nodes

file_path = "eua-dataset-master/eua-dataset-master/edge-servers/site-optus-melbCBD.csv"
zone_node_ids = {
    1: [304365, 9026103, 304366, 135011, 101636, 135045, 42987, 302516],
    2: [101373, 9009845, 130005, 134901, 134680, 303255, 9013096],
    3: [134574, 134906, 302517, 134454, 49873, 301895, 50151, 134990, 301896],
    4: [101381, 461423, 304060, 302923, 302854, 9009843, 49630, 135213],
    5: [134317, 301393, 10003238, 304368, 50226, 47316, 302571, 50686, 134733, 304369],
    6: [135237, 9002262, 135073, 305394, 304744, 10003026, 134453, 51576, 11590, 134360],
    7: [134754, 130439, 301240, 134565, 301361, 301383, 135330],
    8: [134329, 135253, 51718, 303712, 51622, 304434, 301382],
    9: [301388, 44125, 303676, 10004167, 301386, 134386, 301645, 9014605, 9014989],
    10: [134403, 301208, 44101, 134554, 11600, 9015396, 306249, 134980, 11601, 301658],
    11: [135009, 101385, 11571, 41660, 303652, 50669, 134941, 134822],
    12: [51590, 206082, 9014611, 304562, 34603, 304364, 303710, 134449],
    13: [135390, 135143, 404118, 10003027, 11593, 11591, 9001289],
    14: [304370, 135231, 135306, 11579, 10004576, 301205, 11581],
    15: [134923, 53003, 134245, 11599, 304371, 134547, 9009844, 134872, 304363, 134857]
}

all_nodes = load_edge_nodes(file_path, zone_node_ids)

zones = {zone_id: Zone(zone_id, [node for node_id in node_ids for node in all_nodes if node.site_id == node_id])
         for zone_id, node_ids in zone_node_ids.items()}

# Sort nodes in each zone by CPU frequency and reassign site_id
for zone_id, zone in zones.items():
    sorted_nodes = sorted(zone.nodes, key=lambda node: node.cpu_frequency)
    for idx, node in enumerate(sorted_nodes):
        node.site_id = idx + 1
    zone.nodes = sorted_nodes
# Display sorted zones
for zone_id, zone in zones.items():
    print(f"Zone {zone_id}:")
    for node in zone.nodes:
        print(node)
    print()
# Out:
# Zone 1:
# 1-Optus Site 318-326 Spencer St MELBOURNE: (-37.812934000000006, 144.952075), CPU: 2.4 GHz, Capacity: 17000 MB, Available RAM: 17000 MB
# 2-Vodafone Site Building C William Angliss Institute 555 La Trobe Street MELBOURNE VIC 3000: (-37.813175, 144.952919), CPU: 2.7 GHz, Capacity: 23000 MB, Available RAM: 23000 MB
# 3-Optus Site 450 LaTrobe St MELBOURNE: (-37.812343, 144.954135), CPU: 3.0 GHz, Capacity: 20000 MB, Available RAM: 20000 MB
# 4-Optus Site CGU Centre 485 Latrobe Street MELBOURNE: (-37.812799, 144.954686), CPU: 3.3 GHz, Capacity: 21000 MB, Available RAM: 21000 MB
# 5-Nubrick House 271 William Street MELBOURNE: (-37.812653000000005, 144.956622), CPU: 3.3 GHz, Capacity: 21000 MB, Available RAM: 21000 MB
# 6-CGU Bldg 485 La Trobe Street MELBOURNE: (-37.81285, 144.955026), CPU: 3.6 GHz, Capacity: 16000 MB, Available RAM: 16000 MB
# 7-Optus Site Flagstaff Station 433 Latrobe Street MELBOURNE: (-37.811928, 144.956414), CPU: 3.6 GHz, Capacity: 19000 MB, Available RAM: 19000 MB
# 8-Upper Flagstaff Station MELBOURNE: (-37.812379, 144.956402), CPU: 3.6 GHz, Capacity: 16000 MB, Available RAM: 16000 MB
#
# Zone 2:
# 1-Empire Apartments 402-408 La Trobe Street MELBOURNE: (-37.811269, 144.957909), CPU: 2.4 GHz, Capacity: 21000 MB, Available RAM: 21000 MB
# 2-Optus Site 250 Queen St MELBOURNE: (-37.812711, 144.959971), CPU: 2.4 GHz, Capacity: 19000 MB, Available RAM: 19000 MB
# 3-Optus Minicell SE Cnr Queen St and Latrobe St MELBOURNE: (-37.811022, 144.959234), CPU: 2.7 GHz, Capacity: 19000 MB, Available RAM: 19000 MB
# 4-CMTS Site 235 Queen St MELBOURNE: (-37.813381, 144.95961200000002), CPU: 3.0 GHz, Capacity: 18000 MB, Available RAM: 18000 MB
# 5-Optus Site Lonsdale/Queen 250 Queen St MELBOURNE: (-37.812899, 144.959886), CPU: 3.3 GHz, Capacity: 19000 MB, Available RAM: 19000 MB
# 6-Optus Rooftop Site Mitchell House 283 Elizabeth Street MELBOURNE: (-37.81215, 144.96195500000002), CPU: 3.3 GHz, Capacity: 21000 MB, Available RAM: 21000 MB
# 7-Optus Site Queen St 250 Queen St MELBOURNE: (-37.812723, 144.960164), CPU: 3.6 GHz, Capacity: 21000 MB, Available RAM: 21000 MB
#
# Zone 3:
# 1-Optus Site Lonsdale/Elizabeth Elizabeth & Lonsdale MELBOURNE: (-37.811978, 144.96238799999998), CPU: 2.4 GHz, Capacity: 21000 MB, Available RAM: 21000 MB
# 2-Optus/Telstra Site cnr Elizabeth & La Trobe Sts MELBOURNE: (-37.810219, 144.9618), CPU: 2.4 GHz, Capacity: 22000 MB, Available RAM: 22000 MB
# 3-Optus/Vodafone Site 6/211 La Trobe St MELBOURNE: (-37.810065, 144.963281), CPU: 2.4 GHz, Capacity: 23000 MB, Available RAM: 23000 MB
# 4-Optus Site CBD North 360 Elizabeth St MELBOURNE: (-37.811678, 144.962783), CPU: 2.7 GHz, Capacity: 18000 MB, Available RAM: 18000 MB
# 5-Legacy House 283 Swanston Street MELBOURNE: (-37.811251, 144.964157), CPU: 3.0 GHz, Capacity: 23000 MB, Available RAM: 23000 MB
# 6-Optus Site Museum Station Cnr Latrobe and Elizabeth Sts MELBOURNE: (-37.809885, 144.963286), CPU: 3.0 GHz, Capacity: 23000 MB, Available RAM: 23000 MB
# 7-Optus Site Melbourne Central Tower 360 Elizabeth St MELBOURNE: (-37.811126, 144.96211599999998), CPU: 3.3 GHz, Capacity: 23000 MB, Available RAM: 23000 MB
# 8-Optus/Telstra Site cnr Swanston & La Trobe Sts MELBOURNE: (-37.809538, 144.964091), CPU: 3.3 GHz, Capacity: 23000 MB, Available RAM: 23000 MB
# 9-cnr Elizabeth & La Trobe Streets MELBOURNE: (-37.810911, 144.96268999999998), CPU: 3.6 GHz, Capacity: 18000 MB, Available RAM: 18000 MB
#
# Zone 4:
# 1-CMTS Site 287-293 Exhibition St MELBOURNE: (-37.809081, 144.96893), CPU: 2.4 GHz, Capacity: 19000 MB, Available RAM: 19000 MB
# 2-50 Lonsdale St MELBOURNE: (-37.809356, 144.970729), CPU: 2.7 GHz, Capacity: 22000 MB, Available RAM: 22000 MB
# 3-Level 33 Casselden Place 235 Spring Street MELBOURNE: (-37.809041, 144.97182800000002), CPU: 3.0 GHz, Capacity: 23000 MB, Available RAM: 23000 MB
# 4-Optus Minicell SE Cnr Exhibition St and Lonsdale St MELBOURNE: (-37.810269, 144.96986299999998), CPU: 3.0 GHz, Capacity: 22000 MB, Available RAM: 22000 MB
# 5-Casselden Place 2 Lonsdale St MELBOURNE: (-37.809264, 144.971708), CPU: 3.3 GHz, Capacity: 18000 MB, Available RAM: 18000 MB
# 6-Telstra/Vodafone Site 43 Lonsdale St MELBOURNE: (-37.809969, 144.97078), CPU: 3.6 GHz, Capacity: 17000 MB, Available RAM: 17000 MB
# 7-222 Exhibition St MELBOURNE: (-37.810641, 144.970534), CPU: 3.6 GHz, Capacity: 23000 MB, Available RAM: 23000 MB
# 8-Optus Site TAC Building 222 Exhibition Street MELBOURNE: (-37.810382, 144.971223), CPU: 3.6 GHz, Capacity: 16000 MB, Available RAM: 16000 MB
#
# Zone 5:
# 1-Optus Site CBD123 Cnr Bourkr & Exhibition Streets MELBOURNE: (-37.812122, 144.97071), CPU: 2.4 GHz, Capacity: 17000 MB, Available RAM: 17000 MB
# 2-Optus Site Minicell - Spring & Collins 14-16 Collins St MELBOURNE: (-37.813463, 144.973217), CPU: 2.4 GHz, Capacity: 18000 MB, Available RAM: 18000 MB
# 3-Optus Site 14-16 Collins St MELBOURNE: (-37.813573, 144.97340400000002), CPU: 2.4 GHz, Capacity: 19000 MB, Available RAM: 19000 MB
# 4-Optus/Telstra Site cnr Bourke & Exhibition Sts MELBOURNE: (-37.812088, 144.97083600000002), CPU: 2.7 GHz, Capacity: 19000 MB, Available RAM: 19000 MB
# 5-136 Exhibition St MELBOURNE: (-37.81239, 144.9712), CPU: 3.0 GHz, Capacity: 17000 MB, Available RAM: 17000 MB
# 6-Optus/Telstra Site cnr Collins & Exhibition Sts MELBOURNE: (-37.813545, 144.971705), CPU: 3.0 GHz, Capacity: 17000 MB, Available RAM: 17000 MB
# 7-Optus Site 10 Bourke St MELBOURNE: (-37.811533, 144.972614), CPU: 3.3 GHz, Capacity: 16000 MB, Available RAM: 16000 MB
# 8-Level 6 / 161 Collins Street MELBOURNE: (-37.81354, 144.971421), CPU: 3.3 GHz, Capacity: 20000 MB, Available RAM: 20000 MB
# 9-20-30 Bourke St MELBOURNE: (-37.811398, 144.972672), CPU: 3.6 GHz, Capacity: 17000 MB, Available RAM: 17000 MB
# 10-Parliament Underground Station MELBOURNE: (-37.811313, 144.972958), CPU: 3.6 GHz, Capacity: 22000 MB, Available RAM: 22000 MB
#
# Zone 6:
# 1-Optus Site BHP Petroleum Plaza 120 Collins Street MELBOURNE: (-37.815777, 144.970508), CPU: 2.4 GHz, Capacity: 18000 MB, Available RAM: 18000 MB
# 2-Wilson Parking 114 Flinders Street MELBOURNE: (-37.816217, 144.970928), CPU: 2.7 GHz, Capacity: 21000 MB, Available RAM: 21000 MB
# 3-Optus Site Minicell-Flinders & Exhibition 82 Flinders Street MELBOURNE: (-37.816011, 144.972058), CPU: 3.0 GHz, Capacity: 20000 MB, Available RAM: 20000 MB
# 4-CMTS Site Penthouse 71 Collins St MELBOURNE: (-37.814265, 144.971685), CPU: 3.0 GHz, Capacity: 19000 MB, Available RAM: 19000 MB
# 5-ANZ Bank Tower 55 Collins Street MELBOURNE: (-37.814225, 144.971971), CPU: 3.0 GHz, Capacity: 18000 MB, Available RAM: 18000 MB
# 6-8 Exhibition St MELBOURNE: (-37.815371, 144.973076), CPU: 3.3 GHz, Capacity: 19000 MB, Available RAM: 19000 MB
# 7-Spring and Flinders ucell Optus North West corner Spring and Flinders St MELBOURNE: (-37.81517, 144.97476), CPU: 3.3 GHz, Capacity: 20000 MB, Available RAM: 20000 MB
# 8-Optus Site Collins PLace/ANZ Tower 55 Collins St MELBOURNE: (-37.814896000000005, 144.971668), CPU: 3.3 GHz, Capacity: 20000 MB, Available RAM: 20000 MB
# 9-Optus microcell - Cnr Spring St & Flinders St MELBOURNE: (-37.815195, 144.974409), CPU: 3.6 GHz, Capacity: 16000 MB, Available RAM: 16000 MB
# 10-Optus Site 101 Collins St (Pac Dun) 101 Collins St MELBOURNE: (-37.814263, 144.972105), CPU: 3.6 GHz, Capacity: 16000 MB, Available RAM: 16000 MB
#
# Zone 7:
# 1-Optus Site Minicell - Lonsdale & Russell 177-183 Lonsdale St MELBOURNE: (-37.810996, 144.967095), CPU: 2.4 GHz, Capacity: 18000 MB, Available RAM: 18000 MB
# 2-CMTS Site 180 Russell St MELBOURNE: (-37.812084000000006, 144.967997), CPU: 2.7 GHz, Capacity: 21000 MB, Available RAM: 21000 MB
# 3-Optus Site cnr Bourke & Swanston Sts MELBOURNE: (-37.813447, 144.966028), CPU: 2.7 GHz, Capacity: 16000 MB, Available RAM: 16000 MB
# 4-Optus/Telstra Site cnr Russell & Bourke Sts MELBOURNE: (-37.812857, 144.96843), CPU: 3.0 GHz, Capacity: 17000 MB, Available RAM: 17000 MB
# 5-Optus Site Bourke/Russell 175 Bourke St MELBOURNE: (-37.812845, 144.968248), CPU: 3.3 GHz, Capacity: 19000 MB, Available RAM: 19000 MB
# 6-Optus Site Minicell - Town Hall 134-142 Swanston Street MELBOURNE: (-37.814398, 144.96632), CPU: 3.3 GHz, Capacity: 20000 MB, Available RAM: 20000 MB
# 7-CMTS Site cnr Swanston & Lonsdale Sts MELBOURNE: (-37.811627, 144.965056), CPU: 3.6 GHz, Capacity: 19000 MB, Available RAM: 19000 MB
#
# Zone 8:
# 1-Optus Site Lonsdale/Swanston 253 Lonsdale St MELBOURNE: (-37.811625, 144.96491899999998), CPU: 2.4 GHz, Capacity: 19000 MB, Available RAM: 19000 MB
# 2-S/E Cnr Bourke & Elizabeth Sts MELBOURNE: (-37.814395000000005, 144.963537), CPU: 2.4 GHz, Capacity: 19000 MB, Available RAM: 19000 MB
# 3-Optus Site Minicell - Little Bourke & Swa Ltl Bourke & Swanston St MELBOURNE: (-37.812578, 144.96531399999998), CPU: 2.7 GHz, Capacity: 16000 MB, Available RAM: 16000 MB
# 4-Vodafone Site 195 Swanston St MELBOURNE: (-37.813167, 144.965468), CPU: 3.0 GHz, Capacity: 18000 MB, Available RAM: 18000 MB
# 5-Vodafone Microcell Cnr Bourke & Elizabeth Streets MELBOURNE: (-37.814257, 144.96337), CPU: 3.3 GHz, Capacity: 18000 MB, Available RAM: 18000 MB
# 6-Optus/Telstra Site cnr Collins & Elizabeth Sts MELBOURNE: (-37.816122, 144.964421), CPU: 3.3 GHz, Capacity: 17000 MB, Available RAM: 17000 MB
# 7-Optus/Vodafone Site 341-357 Bourke St MELBOURNE: (-37.814484, 144.9635), CPU: 3.6 GHz, Capacity: 23000 MB, Available RAM: 23000 MB
#
# Zone 9:
# 1-Telstra/Optus Site cnr Russell & Collins Sts MELBOURNE: (-37.814765, 144.969286), CPU: 2.4 GHz, Capacity: 21000 MB, Available RAM: 21000 MB
# 2-Optus/Vodafone Site 55 Swanston Walk MELBOURNE: (-37.816206, 144.966634), CPU: 2.4 GHz, Capacity: 21000 MB, Available RAM: 21000 MB
# 3-Optus Rooftop Site 287 Collins Street MELBOURNE: (-37.81631, 144.964351), CPU: 2.4 GHz, Capacity: 16000 MB, Available RAM: 16000 MB
# 4-Hyatt Hotel 123 Collins St MELBOURNE: (-37.815309, 144.969476), CPU: 2.7 GHz, Capacity: 22000 MB, Available RAM: 22000 MB
# 5-161 Collins St Carpark MELBOURNE: (-37.815387, 144.96881499999998), CPU: 3.0 GHz, Capacity: 18000 MB, Available RAM: 18000 MB
# 6-Federation Square North -V 164A Flinders Street MELBOURNE: (-37.816790000000005, 144.96918), CPU: 3.3 GHz, Capacity: 18000 MB, Available RAM: 18000 MB
# 7-Customer Site 271 Collins Street MELBOURNE: (-37.816496, 144.96509), CPU: 3.3 GHz, Capacity: 22000 MB, Available RAM: 22000 MB
# 8-cnr Collins & Swanston Streets Westin Hotel MELBOURNE: (-37.815488, 144.966824), CPU: 3.6 GHz, Capacity: 20000 MB, Available RAM: 20000 MB
# 9-Optus Site Collins & Swanston Cnr Collins & Swanston Sts MELBOURNE: (-37.815549, 144.966686), CPU: 3.6 GHz, Capacity: 22000 MB, Available RAM: 22000 MB
#
# Zone 10:
# 1-Optus Site Flinders/Elizabeth 1 Elizabeth St MELBOURNE: (-37.818166, 144.964831), CPU: 2.4 GHz, Capacity: 20000 MB, Available RAM: 20000 MB
# 2-BTS Site 38465D Treasure Funds House 50 Market Street MELBOURNE: (-37.818151, 144.96081), CPU: 2.4 GHz, Capacity: 21000 MB, Available RAM: 21000 MB
# 3-1 Elizabeth Street cnr Flinders St MELBOURNE: (-37.818018, 144.964596), CPU: 2.7 GHz, Capacity: 17000 MB, Available RAM: 17000 MB
# 4-Telstra IBC 401 Collins St MELBOURNE: (-37.817386, 144.96123), CPU: 2.7 GHz, Capacity: 17000 MB, Available RAM: 17000 MB
# 5-Optus Sire Minicell - Market & Flinders 50 Market St MELBOURNE: (-37.818218, 144.96070500000002), CPU: 2.7 GHz, Capacity: 21000 MB, Available RAM: 21000 MB
# 6-333 Collins Street MELBOURNE: (-37.816822, 144.963209), CPU: 3.0 GHz, Capacity: 18000 MB, Available RAM: 18000 MB
# 7-Optus Site Bridge Information Systems 360 Collins St MELBOURNE: (-37.817261, 144.962515), CPU: 3.3 GHz, Capacity: 20000 MB, Available RAM: 20000 MB
# 8-Optus Site National Mutual Building 447 Collins St MELBOURNE: (-37.818162, 144.959934), CPU: 3.3 GHz, Capacity: 17000 MB, Available RAM: 17000 MB
# 9-Optus Site 1 William St MELBOURNE: (-37.819471, 144.960069), CPU: 3.3 GHz, Capacity: 21000 MB, Available RAM: 21000 MB
# 10-367 Collins Street Optus Centre MELBOURNE: (-37.817303, 144.962344), CPU: 3.6 GHz, Capacity: 22000 MB, Available RAM: 22000 MB
#
# Zone 11:
# 1-Optus Site Commonwealth Bank 385 Bourke Street MELBOURNE: (-37.815196, 144.96296999999998), CPU: 2.4 GHz, Capacity: 18000 MB, Available RAM: 18000 MB
# 2-Optus Site Bourke/Queen St Bourke & Queen Sts MELBOURNE: (-37.814989, 144.96090800000002), CPU: 2.4 GHz, Capacity: 23000 MB, Available RAM: 23000 MB
# 3-Benjamin House 358-360 Little Collins St MELBOURNE: (-37.815461, 144.962656), CPU: 2.7 GHz, Capacity: 16000 MB, Available RAM: 16000 MB
# 4-360 Collins St Collins Wales Building MELBOURNE: (-37.816356, 144.962313), CPU: 3.0 GHz, Capacity: 22000 MB, Available RAM: 22000 MB
# 5-100 Queen Street MELBOURNE: (-37.816209, 144.961635), CPU: 3.3 GHz, Capacity: 16000 MB, Available RAM: 16000 MB
# 6-Optus/Telstra Site cnr Collins & Queen Sts MELBOURNE: (-37.816891, 144.961957), CPU: 3.3 GHz, Capacity: 17000 MB, Available RAM: 17000 MB
# 7-Optus Site Minicell - Collins & Queen 379 Collins St MELBOURNE: (-37.817069, 144.961828), CPU: 3.3 GHz, Capacity: 17000 MB, Available RAM: 17000 MB
# 8-394 Collins St MELBOURNE: (-37.81653, 144.961967), CPU: 3.6 GHz, Capacity: 16000 MB, Available RAM: 16000 MB
#
# Zone 12:
# 1-454 Collins Street MELBOURNE: (-37.815992, 144.961028), CPU: 2.4 GHz, Capacity: 22000 MB, Available RAM: 22000 MB
# 2-Vodafone Microcell Cnr Collins & William Streets MELBOURNE: (-37.81751, 144.959237), CPU: 2.4 GHz, Capacity: 19000 MB, Available RAM: 19000 MB
# 3-Hutchison Site City Queen 2 105 Queen St cnr Lt Collins St MELBOURNE: (-37.816158, 144.96070600000002), CPU: 2.7 GHz, Capacity: 18000 MB, Available RAM: 18000 MB
# 4-Optus Site Melbourne City West 454 Collins St MELBOURNE: (-37.817384, 144.959217), CPU: 2.7 GHz, Capacity: 20000 MB, Available RAM: 20000 MB
# 5-Optus Rooftop Site 520 Bourke Street MELBOURNE: (-37.815296, 144.958369), CPU: 3.0 GHz, Capacity: 17000 MB, Available RAM: 17000 MB
# 6-Optus Site 454 Collins St MELBOURNE: (-37.817483, 144.959445), CPU: 3.0 GHz, Capacity: 16000 MB, Available RAM: 16000 MB
# 7-140 William Street MELBOURNE: (-37.815891, 144.958861), CPU: 3.3 GHz, Capacity: 19000 MB, Available RAM: 19000 MB
# 8-Telstra/Optus Site 114 William St MELBOURNE: (-37.816299, 144.95902), CPU: 3.6 GHz, Capacity: 22000 MB, Available RAM: 22000 MB
#
# Zone 13:
# 1-Optus Site Minicell - Lonsdale & William Lonsdale & William Streets MELBOURNE: (-37.813963, 144.957301), CPU: 2.4 GHz, Capacity: 20000 MB, Available RAM: 20000 MB
# 2-Optus Site Minicell - Lonsdale & King 600-610 Lonsdale St MELBOURNE: (-37.814431, 144.954653), CPU: 2.7 GHz, Capacity: 20000 MB, Available RAM: 20000 MB
# 3-225 King Street MELBOURNE: (-37.814905, 144.95491299999998), CPU: 3.0 GHz, Capacity: 20000 MB, Available RAM: 20000 MB
# 4-Optus Minicell - Lon_Spencer Corner Spencer and Lonsdale St MELBOURNE: (-37.81524, 144.95256), CPU: 3.3 GHz, Capacity: 21000 MB, Available RAM: 21000 MB
# 5-Citipower House 628 Bourke Street MELBOURNE: (-37.815858, 144.954818), CPU: 3.3 GHz, Capacity: 16000 MB, Available RAM: 16000 MB
# 6-Marland House 570 Bourke Street MELBOURNE: (-37.815493, 144.95671399999998), CPU: 3.6 GHz, Capacity: 19000 MB, Available RAM: 19000 MB
# 7-Bourke Place 600 Bourke Street MELBOURNE: (-37.815975, 144.955905), CPU: 3.6 GHz, Capacity: 19000 MB, Available RAM: 19000 MB
#
# Zone 14:
# 1-Optus Site AMP Square 121 William St MELBOURNE: (-37.815793, 144.958295), CPU: 2.4 GHz, Capacity: 21000 MB, Available RAM: 21000 MB
# 2-Optus Site BHP House 140 William Street MELBOURNE: (-37.816467, 144.958334), CPU: 2.7 GHz, Capacity: 19000 MB, Available RAM: 19000 MB
# 3-625 Lt Collins St MELBOURNE: (-37.818202, 144.954367), CPU: 2.7 GHz, Capacity: 20000 MB, Available RAM: 20000 MB
# 4-Optus Site Minicell - Bourke & William 121 William St MELBOURNE: (-37.81607, 144.957254), CPU: 3.0 GHz, Capacity: 17000 MB, Available RAM: 17000 MB
# 5-99 King Street MELBOURNE: (-37.817779, 144.95596899999998), CPU: 3.0 GHz, Capacity: 18000 MB, Available RAM: 18000 MB
# 6-Stock Exchange Bldg 530 Collins Street MELBOURNE: (-37.818071, 144.957211), CPU: 3.3 GHz, Capacity: 19000 MB, Available RAM: 19000 MB
# 7-KING ST (3144 REPLACEMENT) -V 530 Collins Street MELBOURNE: (-37.81808, 144.95692), CPU: 3.6 GHz, Capacity: 21000 MB, Available RAM: 21000 MB
#
# Zone 15:
# 1-Optus Site Flinders/William 1 William St MELBOURNE: (-37.819576, 144.95985), CPU: 2.4 GHz, Capacity: 23000 MB, Available RAM: 23000 MB
# 2-Optus Minicell NE Cnr Spencer St and Collins St MELBOURNE: (-37.819101, 144.954229), CPU: 2.4 GHz, Capacity: 17000 MB, Available RAM: 17000 MB
# 3-Optus Site Minicell - King & Flinders King & Flinders St MELBOURNE: (-37.820123, 144.957552), CPU: 2.4 GHz, Capacity: 19000 MB, Available RAM: 19000 MB
# 4-Hotham Hotel 2 Spencer St MELBOURNE: (-37.820744, 144.955485), CPU: 2.4 GHz, Capacity: 20000 MB, Available RAM: 20000 MB
# 5-452-470 Flinders Street MELBOURNE: (-37.81922, 144.958485), CPU: 2.7 GHz, Capacity: 22000 MB, Available RAM: 22000 MB
# 6-Optus Site Minicell - Flinders and Spencer 2 Spencer St MELBOURNE: (-37.82091, 144.955155), CPU: 2.7 GHz, Capacity: 23000 MB, Available RAM: 23000 MB
# 7-Optus Site Rialto 525 Collins Street MELBOURNE: (-37.818494, 144.957705), CPU: 3.0 GHz, Capacity: 17000 MB, Available RAM: 17000 MB
# 8-Optus Site Minicell - King & Collins 539-557 Collins St MELBOURNE: (-37.818656, 144.956626), CPU: 3.0 GHz, Capacity: 16000 MB, Available RAM: 16000 MB
# 9-Rialto Towers 525 Collins Street MELBOURNE: (-37.81852, 144.95714099999998), CPU: 3.3 GHz, Capacity: 22000 MB, Available RAM: 22000 MB
# 10-Optus Site 539-557 Collins St MELBOURNE: (-37.818474, 144.956805), CPU: 3.6 GHz, Capacity: 16000 MB, Available RAM: 16000 MB

# %%
class User:
    def __init__(self, user_id, latitude, longitude):
        self.user_id = user_id
        self.latitude = latitude
        self.longitude = longitude

    def __repr__(self):
        return f"User({self.user_id}): ({self.latitude}, {self.longitude})"


class Request:
    def __init__(self, user_id, request_type, size, timestamp):
        self.user_id = user_id
        self.request_type = request_type
        self.size = size
        self.timestamp = timestamp

    def __repr__(self):
        return f"Request(User: {self.user_id}, Type: {self.request_type}, Size: {self.size}MB, Timestamp: {self.timestamp})"

# %%
def load_users(file_path):
    df = pd.read_csv(file_path, delimiter=',')
    users = []
    for index, row in df.iterrows():
        user_id = index + 1
        latitude = row['Latitude']
        longitude = row['Longitude']
        user = User(user_id, latitude, longitude)
        users.append(user)
    logging.info(f"Loaded {len(users)} users from {file_path}")
    return users



def load_invocation_data(file_path):
    if os.path.exists(file_path):
        df = pd.read_csv(file_path)
        logging.info(f"Loaded invocation data from {file_path}")
        return df
    else:
        logging.error(f"File not found: {file_path}")
        return None

def load_duration_data(file_path):
    if os.path.exists(file_path):
        df = pd.read_csv(file_path)
        logging.info(f"Loaded duration data from {file_path}")
        return df
    else:
        logging.error(f"File not found: {file_path}")
        return None

def filter_functions_by_hashowner(data, hash_owner):
    filtered_data = data[data['HashOwner'] == hash_owner]
    logging.info(f"Filtered functions by hash owner {hash_owner}, resulting in {len(filtered_data)} entries")
    return filtered_data

def generate_requests_zipf(beta, num_requests, K):
    ranks = np.arange(1, K + 1)
    weights = 1 / np.power(ranks, beta)
    weights /= weights.sum()
    return np.random.choice(ranks, size=num_requests, p=weights)

def generate_user_requests(users, beta, ranked_functions, num_requests_per_timeslot):
    K = len(ranked_functions)
    total_time_slots = 100  # Assume 1 day, each day has 1440 minutes
    requests = []

    for timestamp in range(total_time_slots):
        for user in users:
            user_id = user.user_id
            # Generate request types randomly according to Zipf-β distribution
            request_types = generate_requests_zipf(beta, num_requests_per_timeslot, K)
            for request_type_rank in request_types:
                function_info = ranked_functions[request_type_rank]
                request_type = function_info[0]
                size = function_info[2]
                requests.append(Request(user_id, request_type_rank, size, timestamp))
                logging.debug(f"Generated request: {requests[-1]}")
    logging.info(f"Generated a total of {len(requests)} requests")
    return requests



user_file_path = "eua-dataset-master/eua-dataset-master/users/users-melbcbd-generated.csv"
users = load_users(user_file_path)

extracted_folder = "extracted_files/azure-functions-master"
invocation_file_paths = [os.path.join(extracted_folder, "invocations_per_function_md.anon.d01.csv")]
duration_file_paths = [os.path.join(extracted_folder, "function_durations_percentiles.anon.d01.csv")]

invocation_data = [load_invocation_data(file) for file in invocation_file_paths if os.path.exists(file)]
duration_data = [load_duration_data(file) for file in duration_file_paths if os.path.exists(file)]

invocation_data = [df for df in invocation_data if df is not None]
duration_data = [df for df in duration_data if df is not None]

if invocation_data:
    all_invocations = pd.concat(invocation_data, ignore_index=True)
    logging.info("Combined all invocation data into a single DataFrame")

if duration_data:
    all_durations = pd.concat(duration_data, ignore_index=True)
    logging.info("Combined all duration data into a single DataFrame")

selected_hash_owner = '98f3fe1d01789fc2d8ab1dc9cd9a31d51fcbf1936e36a47526280c95ec0cd944'
filtered_functions = filter_functions_by_hashowner(all_invocations, selected_hash_owner)
filtered_durations = filter_functions_by_hashowner(all_durations, selected_hash_owner)

filtered_functions['TotalInvocations'] = filtered_functions.loc[:, '1':'1440'].sum(axis=1)
request_counts = filtered_functions.groupby('HashFunction')['TotalInvocations'].sum().sort_values(ascending=False)
selected_functions = request_counts.head(50)
logging.info(f"Selected top 50 functions based on total invocations")

function_sizes = filtered_durations.groupby('HashFunction')['Average'].mean()
function_sizes = function_sizes[selected_functions.index]

min_size = 20  # MB
max_size = 250  # MB
sizes = np.interp(function_sizes, (function_sizes.min(), function_sizes.max()), (min_size, max_size))

ranked_functions_list = [(i + 1, selected_functions.index[i], selected_functions.iloc[i], round(sizes[i])) for i in range(50)]
logging.info("Ranked functions and assigned sizes based on average execution time")

ranked_functions = {rank: (hash_function, invocations, size) for rank, hash_function, invocations, size in ranked_functions_list}

print("Ranked Functions:")
for rank, (hash_function, invocations, size) in ranked_functions.items():
    print(f"Rank {rank}: Function {hash_function}, Invocations: {invocations}, Estimated Size: {size:.2f}MB")

# beta = 1.0  # Adjust this value as needed
# num_requests_per_timeslot =   # Assume each user generates 2 requests per timeslot
# requests = generate_user_requests(users, beta, ranked_functions, num_requests_per_timeslot)

# print("Generated Requests:")
# for request in requests[:10]:  # Display the first 10 requests
#     print(request)
# Out:
# Ranked Functions:
# Rank 1: Function 85cff28b83792428e039e986e5d5554318a9678f111ec9a6f65ae2956f25ed18, Invocations: 1985730, Estimated Size: 21.00MB
# Rank 2: Function 6c871093253858350d730f80cfbc5109aa2529d9cda37341989ea8854485663e, Invocations: 1984364, Estimated Size: 21.00MB
# Rank 3: Function 2f5fefaa527316e6630e589235511e7f13781841babdc4c15ecc33a28204c9b4, Invocations: 22307, Estimated Size: 28.00MB
# Rank 4: Function 331a2f8a0962ecde7e31c20b068efc25c79deb733b3bfe4094dffcb2d7be4a9f, Invocations: 17228, Estimated Size: 20.00MB
# Rank 5: Function 2a48e6ede657e3a9cbc0d374df1bb55c25620bca2787e98e26af975927981f13, Invocations: 11482, Estimated Size: 23.00MB
# Rank 6: Function 4cd30dc5400766df9735dd7616dda2ef599e4ca10b3c4cbceaca08c0ff6a7baa, Invocations: 7288, Estimated Size: 21.00MB
# Rank 7: Function 94f7fff69733d5538b07436d65e1b73cac99d26705b43b3d623892302123fdde, Invocations: 3470, Estimated Size: 38.00MB
# Rank 8: Function b937c1821c6ede34645cbf2d9f6cc8bcd679c7398da078bcb23357beeb05af88, Invocations: 2763, Estimated Size: 22.00MB
# Rank 9: Function c010c380f0f37f25ac5c89645d592eda3e3f03f61488730b943e8dfdab8b1edf, Invocations: 1523, Estimated Size: 21.00MB
# Rank 10: Function 97ea941c59141a5b0c72b46bb2d0e7857ba485eb8710e9cd38b1e10388935077, Invocations: 1441, Estimated Size: 45.00MB
# Rank 11: Function 63008ff9fd57ba942de974bd577b0050a24909e751563c1bd4242445f8ed18a4, Invocations: 1440, Estimated Size: 20.00MB
# Rank 12: Function 163c0483a642106f4adf510ae3e04fdac139de9a46f0af9e0d6a1fcf9a77d6be, Invocations: 1277, Estimated Size: 46.00MB
# Rank 13: Function 894efb748ccbe96a26116facdb86c42acf0757079afe69a7479a80d3bd56196f, Invocations: 929, Estimated Size: 75.00MB
# Rank 14: Function 2fe49ebc674e9e2611a6ac3bd50b580b1f13556d5de0e0d6ad4f1957d4e889ea, Invocations: 531, Estimated Size: 46.00MB
# Rank 15: Function f75af109ee87d485e18377e1652dcf079b82303f920097ba1207362d2aa88fe6, Invocations: 531, Estimated Size: 22.00MB
# Rank 16: Function 448f52cbecea4af606af9f2a5636ae7a1f7e144397318b3948fdbe3faf74c1a5, Invocations: 527, Estimated Size: 21.00MB
# Rank 17: Function a57bac412d613fe8bf26af57e2e4fe2054274e6fe66d120b1ef3a9315c38a5cc, Invocations: 492, Estimated Size: 35.00MB
# Rank 18: Function 716efccae7dd2d748c05b5732d13f6f9b949b05bb2a9e96adffa628f1f930105, Invocations: 288, Estimated Size: 28.00MB
# Rank 19: Function 1948876d67f73860a97e6a6f57dad339f21f0188ff3eff1bf6f3df7f37606e71, Invocations: 288, Estimated Size: 22.00MB
# Rank 20: Function c19ca713b1c417fed2f58abff4776c4401eb09250b6eb2ee89b19df27bbc959c, Invocations: 288, Estimated Size: 23.00MB
# Rank 21: Function e5e0934be1d647119514422b4a853be02155e49a02c10e57af356f6b09cbeccd, Invocations: 288, Estimated Size: 25.00MB
# Rank 22: Function 59c0892fd7dc4594462ac6db04b3bdc3836137c48a58319bba4fa1fe3312e4e1, Invocations: 288, Estimated Size: 23.00MB
# Rank 23: Function a065c0ecd9c5831da0ab4633608d1154223d0557ac2f7a22cd1194711ba3bfb7, Invocations: 284, Estimated Size: 40.00MB
# Rank 24: Function 1328514642ce9be5cddf542a8c16ff9bbdf32ebba01a7dd5372881016dd9db44, Invocations: 264, Estimated Size: 27.00MB
# Rank 25: Function 27918dfcbdd0de363a7c206900547dd1bae6c63b404fbdd9996001f1c47594c3, Invocations: 253, Estimated Size: 27.00MB
# Rank 26: Function 2ae38897520bc54c84e3083d4aea5ec4607f6864a42d358f0ab425b8df83afa8, Invocations: 250, Estimated Size: 58.00MB
# Rank 27: Function 3896ebfa02c9e5185a4c3d4588589683184a0dbd739ce8f917c6a2cff6e0c415, Invocations: 147, Estimated Size: 59.00MB
# Rank 28: Function 0fde0946720695bda1afe05ca54328fc657404d37e666cc33afe7cabdcc67881, Invocations: 144, Estimated Size: 23.00MB
# Rank 29: Function 3a3c2c2d8c14dc9c32f9d5d495e09c1e3782fd7550efb10241f9bd43bbfa8d9b, Invocations: 97, Estimated Size: 50.00MB
# Rank 30: Function b575d9c85046ac5835339e7a82cb2a4b43ac9e5bbb0fca32cd38386bf69b3ba1, Invocations: 96, Estimated Size: 30.00MB
# Rank 31: Function 0d3252272e0f6be3936b0e8320279df0095ff6116d05e2989fd72982e7608550, Invocations: 96, Estimated Size: 79.00MB
# Rank 32: Function e69a76d82ed8c979b2027787e6e140b7cee91c6c9ac240d50b1b8d677fe5f279, Invocations: 96, Estimated Size: 90.00MB
# Rank 33: Function 44a5573ebe85f67965836ebf6a4a82d0d65256c121052a1e84c6e2cc9555a97c, Invocations: 80, Estimated Size: 24.00MB
# Rank 34: Function d3e5f5f37c3a7cc5d0d305b7a9f05683635edf11a3ff13e54edac2e7edab27ae, Invocations: 77, Estimated Size: 166.00MB
# Rank 35: Function 2ea60799cfb9ea116c19e8233352af05e8683cc26be7bfa7282a4801dabc268b, Invocations: 70, Estimated Size: 62.00MB
# Rank 36: Function fca903c73a3ed5baecd5e033d2decee719840622842e47eddf510eda12613a77, Invocations: 50, Estimated Size: 191.00MB
# Rank 37: Function bd3425d1a5d5a59d213601e35773e9df33da20c580324204dba63209a377ec7c, Invocations: 48, Estimated Size: 165.00MB
# Rank 38: Function de6bec410527749f108d62b95b82abd95e5c82b9b422997966e10338a065c050, Invocations: 48, Estimated Size: 170.00MB
# Rank 39: Function 98eb98bf09aaa634cc6f969f069de7a924f54b2ff86693b448075eca72c60ef1, Invocations: 48, Estimated Size: 146.00MB
# Rank 40: Function b9b0cd742c99583f0a715fa5813675c6e1521226b108ad37b3af4c1e8b38db8a, Invocations: 48, Estimated Size: 89.00MB
# Rank 41: Function e4d1d72cf54834d89ef6af4c5c992d0118ba2bf08b3a2d2b4f722fcf9fa14949, Invocations: 41, Estimated Size: 61.00MB
# Rank 42: Function a427c48fb7af62e738c2b8734a6394faca42dc4288732c29a7e6ad6a0a200f6b, Invocations: 35, Estimated Size: 26.00MB
# Rank 43: Function 95606379707566ba4eb2af0cbf74f9bd4889f0f4ee31d4823cd7d01f0304d692, Invocations: 35, Estimated Size: 30.00MB
# Rank 44: Function 634cc4308a528105904e31bbde4be79a240084de33b63a574d77bf202490de53, Invocations: 34, Estimated Size: 85.00MB
# Rank 45: Function 28bff1b3e5bb814eb4f8b4780e8c9ac09e97194e27899c167697aac614b61c35, Invocations: 32, Estimated Size: 31.00MB
# Rank 46: Function bd0f8c1cfdf1c22cf316438b7a19203026dd95e1e3e0df850523743a7fbf9d00, Invocations: 31, Estimated Size: 47.00MB
# Rank 47: Function f1c924b88698471f94f7538130b5a440b2db98e6501546012febc0bf7c187e85, Invocations: 24, Estimated Size: 142.00MB
# Rank 48: Function 01bab69fcdb985a4232c022d3f78f6663048e94d54479102522f73105cef8554, Invocations: 24, Estimated Size: 47.00MB
# Rank 49: Function 1878e6e5c14c281edb28db1a6bdb6a67feaf544c9909221abe4434f7d22283ed, Invocations: 24, Estimated Size: 48.00MB
# Rank 50: Function 741e02f22338c72258ee79df114995ea5b53d210bb97e29805106ae8b60a1967, Invocations: 24, Estimated Size: 250.00MB
# <ipython-input-5-156c682dedc4>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_functions['TotalInvocations'] = filtered_functions.loc[:, '1':'1440'].sum(axis=1)

# %%
alpha = 0.01
beta = 1.5 # Adjust this value as needed
num_requests_per_timeslot = 20
requests = generate_user_requests(users, beta, ranked_functions, num_requests_per_timeslot)

# %%
def calculate_lambda_n_k_t(users, requests, zones, K, total_time_slots):
    # Initialize dictionary to store the total request load λ_{n,k,t}
    lambda_n_k_t = {}

    # Function to find the nearest node in a given zone for a user
    def find_nearest_node(user, nodes):
        min_distance = float('inf')
        nearest_node = None
        for node in nodes:
            distance = geodesic((user.latitude, user.longitude), (node.latitude, node.longitude)).kilometers
            if distance < min_distance:
                min_distance = distance
                nearest_node = node
        return nearest_node

    # Determine the nearest node for each user within their assigned zone
    user_assignments = {}  # Dictionary to store nearest node for each user
    for user in users:
        nearest_node = None
        nearest_zone = None
        min_distance = float('inf')

        for zone_id, zone in zones.items():
            node = find_nearest_node(user, zone.nodes)
            if node:
                distance = geodesic((user.latitude, user.longitude), (node.latitude, node.longitude)).kilometers
                if distance < min_distance:
                    min_distance = distance
                    nearest_node = node
                    nearest_zone = zone_id

        user_assignments[user.user_id] = (nearest_zone, nearest_node.site_id)

    # Assign requests to the nearest node in their zone and calculate λ_{n,k,t}
    for request in requests:
        user_id = request.user_id
        k = request.request_type  # Container type rank
        t = request.timestamp  # Time slot, assuming 1 time slot = 1 minute

        nearest_zone, nearest_node_id = user_assignments[user_id]
        n = nearest_node_id

        if (nearest_zone, n, k, t) not in lambda_n_k_t:
            lambda_n_k_t[(nearest_zone, n, k, t)] = 0

        lambda_n_k_t[(nearest_zone, n, k, t)] += 1  # Incrementing the count of requests for the nearest node

    return lambda_n_k_t

# %%
total_time_slots=100
K = 50
lambda_n_k_t =calculate_lambda_n_k_t(users, requests, zones, K, total_time_slots)

# %%
def find_max_requests_per_node_per_zone(lambda_n_k_t):
    max_requests_per_zone = {}

    for (zone_id, node_id, k, t), count in lambda_n_k_t.items():
        if zone_id not in max_requests_per_zone:
            max_requests_per_zone[zone_id] = {}

        if k not in max_requests_per_zone[zone_id]:
            max_requests_per_zone[zone_id][k] = count
        else:
            if count > max_requests_per_zone[zone_id][k]:
                max_requests_per_zone[zone_id][k] = count

    return max_requests_per_zone

def calculate_total_size(max_requests_per_zone, ranked_functions):
    total_size_per_zone = {}

    for zone_id in max_requests_per_zone:
        total_size_per_zone[zone_id] = {}
        for k, max_count in max_requests_per_zone[zone_id].items():
            size_per_request = ranked_functions[k][2]
            total_size = max_count * size_per_request
            total_size_per_zone[zone_id][k] = total_size

    return total_size_per_zone

def calculate_total_size_per_zone(total_size_per_zone):
    zone_total_size = {}

    for zone_id, sizes in total_size_per_zone.items():
        zone_total_size[zone_id] = sum(sizes.values())

    return zone_total_size

# Giả sử lambda_n_k_t đã được tính toán
max_requests_per_zone = find_max_requests_per_node_per_zone(lambda_n_k_t)

# Tính toán tổng dung lượng cho từng loại request trong mỗi zone
total_size_per_zone = calculate_total_size(max_requests_per_zone, ranked_functions)

# Tính tổng dung lượng cho từng zone
zone_total_size = calculate_total_size_per_zone(total_size_per_zone)

# In kết quả
for zone_id in zone_total_size:
    total_size = zone_total_size[zone_id]
    print(f"Zone {zone_id}: Tổng dung lượng các loại request: {total_size:.2f} MB")
# Out:
# Zone 6: Tổng dung lượng các loại request: 15115.00 MB
# Zone 4: Tổng dung lượng các loại request: 24927.00 MB
# Zone 15: Tổng dung lượng các loại request: 14236.00 MB
# Zone 13: Tổng dung lượng các loại request: 24742.00 MB
# Zone 8: Tổng dung lượng các loại request: 21335.00 MB
# Zone 7: Tổng dung lượng các loại request: 25477.00 MB
# Zone 2: Tổng dung lượng các loại request: 20988.00 MB
# Zone 9: Tổng dung lượng các loại request: 17894.00 MB
# Zone 10: Tổng dung lượng các loại request: 10970.00 MB
# Zone 12: Tổng dung lượng các loại request: 16328.00 MB
# Zone 1: Tổng dung lượng các loại request: 15167.00 MB
# Zone 14: Tổng dung lượng các loại request: 14310.00 MB
# Zone 11: Tổng dung lượng các loại request: 18646.00 MB
# Zone 5: Tổng dung lượng các loại request: 16235.00 MB
# Zone 3: Tổng dung lượng các loại request: 18989.00 MB

# %%
# Tính toán chi phí khởi tạo và lưu trữ cho từng Zone
for zone in zones.values():
    zone.calculate_costs(ranked_functions)


# Calculate instantiation and retention costs for all zones
for zone in zones.values():
    zone.calculate_costs(ranked_functions)

# Function to calculate communication costs
def calculate_communication_cost(zones, K):
    communication_costs = {}

    for zone_id_1, zone_1 in zones.items():
        for zone_id_2, zone_2 in zones.items():
            if zone_id_1 != zone_id_2:
                # Calculate geographical distance between zone centers
                center_1 = zone_1.get_zone_center()
                center_2 = zone_2.get_zone_center()
                distance = geodesic(center_1, center_2).kilometers

                for k in range(1, K + 1):
                    try:
                        # Calculate minimal and maximal instantiation costs for container type k in both zones
                        min_inst_cost_1 = min(zone_1.instantiation_costs[(node.site_id, k)] for node in zone_1.nodes)
                        max_inst_cost_1 = max(zone_1.instantiation_costs[(node.site_id, k)] for node in zone_1.nodes)
                        min_inst_cost_2 = min(zone_2.instantiation_costs[(node.site_id, k)] for node in zone_2.nodes)
                        max_inst_cost_2 = max(zone_2.instantiation_costs[(node.site_id, k)] for node in zone_2.nodes)

                        # Calculate average min and max costs
                        avg_min_cost = (min_inst_cost_1 + min_inst_cost_2) / 2
                        avg_max_cost = (max_inst_cost_1 + max_inst_cost_2) / 2

                        # Normalize distance to be between 0 and 1
                        max_distance = 100  # Assuming the maximum distance is 100 km for normalization
                        normalized_distance = distance / max_distance

                        # Calculate communication cost
                        comm_cost = avg_min_cost + (avg_max_cost - avg_min_cost) * normalized_distance

                        communication_costs[(zone_id_1, zone_id_2, k)] = comm_cost
                    except KeyError:
                        print(f"Missing instantiation cost for container type {k} in zones {zone_id_1} or {zone_id_2}")

    return communication_costs

# Calculate communication costs for all pairs of zones and all container types
K = 50  # Assuming there are 50 types of containers
communication_costs = calculate_communication_cost(zones, K)

# Print the communication costs for each container type
for (zone_id_1, zone_id_2, k), cost in communication_costs.items():
    print(f"Communication cost for container type {k} between Zone {zone_id_1} and Zone {zone_id_2}: {cost:.2f}")
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# Communication cost for container type 1 between Zone 8 and Zone 14: 5.86
# Communication cost for container type 2 between Zone 8 and Zone 14: 5.86
# Communication cost for container type 3 between Zone 8 and Zone 14: 7.81
# Communication cost for container type 4 between Zone 8 and Zone 14: 5.58
# Communication cost for container type 5 between Zone 8 and Zone 14: 6.41
# Communication cost for container type 6 between Zone 8 and Zone 14: 5.86
# Communication cost for container type 7 between Zone 8 and Zone 14: 10.60
# Communication cost for container type 8 between Zone 8 and Zone 14: 6.13
# Communication cost for container type 9 between Zone 8 and Zone 14: 5.86
# Communication cost for container type 10 between Zone 8 and Zone 14: 12.55
# Communication cost for container type 11 between Zone 8 and Zone 14: 5.58
# Communication cost for container type 12 between Zone 8 and Zone 14: 12.83
# Communication cost for container type 13 between Zone 8 and Zone 14: 20.91
# Communication cost for container type 14 between Zone 8 and Zone 14: 12.83
# Communication cost for container type 15 between Zone 8 and Zone 14: 6.13
# Communication cost for container type 16 between Zone 8 and Zone 14: 5.86
# Communication cost for container type 17 between Zone 8 and Zone 14: 9.76
# Communication cost for container type 18 between Zone 8 and Zone 14: 7.81
# Communication cost for container type 19 between Zone 8 and Zone 14: 6.13
# Communication cost for container type 20 between Zone 8 and Zone 14: 6.41
# Communication cost for container type 21 between Zone 8 and Zone 14: 6.97
# Communication cost for container type 22 between Zone 8 and Zone 14: 6.41
# Communication cost for container type 23 between Zone 8 and Zone 14: 11.15
# Communication cost for container type 24 between Zone 8 and Zone 14: 7.53
# Communication cost for container type 25 between Zone 8 and Zone 14: 7.53
# Communication cost for container type 26 between Zone 8 and Zone 14: 16.17
# Communication cost for container type 27 between Zone 8 and Zone 14: 16.45
# Communication cost for container type 28 between Zone 8 and Zone 14: 6.41
# Communication cost for container type 29 between Zone 8 and Zone 14: 13.94
# Communication cost for container type 30 between Zone 8 and Zone 14: 8.36
# Communication cost for container type 31 between Zone 8 and Zone 14: 22.03
# Communication cost for container type 32 between Zone 8 and Zone 14: 25.09
# Communication cost for container type 33 between Zone 8 and Zone 14: 6.69
# Communication cost for container type 34 between Zone 8 and Zone 14: 46.29
# Communication cost for container type 35 between Zone 8 and Zone 14: 17.29
# Communication cost for container type 36 between Zone 8 and Zone 14: 53.26
# Communication cost for container type 37 between Zone 8 and Zone 14: 46.01
# Communication cost for container type 38 between Zone 8 and Zone 14: 47.40
# Communication cost for container type 39 between Zone 8 and Zone 14: 40.71
# Communication cost for container type 40 between Zone 8 and Zone 14: 24.82
# Communication cost for container type 41 between Zone 8 and Zone 14: 17.01
# Communication cost for container type 42 between Zone 8 and Zone 14: 7.25
# Communication cost for container type 43 between Zone 8 and Zone 14: 8.36
# Communication cost for container type 44 between Zone 8 and Zone 14: 23.70
# Communication cost for container type 45 between Zone 8 and Zone 14: 8.64
# Communication cost for container type 46 between Zone 8 and Zone 14: 13.10
# Communication cost for container type 47 between Zone 8 and Zone 14: 39.59
# Communication cost for container type 48 between Zone 8 and Zone 14: 13.10
# Communication cost for container type 49 between Zone 8 and Zone 14: 13.38
# Communication cost for container type 50 between Zone 8 and Zone 14: 69.71
# Communication cost for container type 1 between Zone 8 and Zone 15: 5.86
# Communication cost for container type 2 between Zone 8 and Zone 15: 5.86
# Communication cost for container type 3 between Zone 8 and Zone 15: 7.81
# Communication cost for container type 4 between Zone 8 and Zone 15: 5.58
# Communication cost for container type 5 between Zone 8 and Zone 15: 6.42
# Communication cost for container type 6 between Zone 8 and Zone 15: 5.86
# Communication cost for container type 7 between Zone 8 and Zone 15: 10.60
# Communication cost for container type 8 between Zone 8 and Zone 15: 6.14
# Communication cost for container type 9 between Zone 8 and Zone 15: 5.86
# Communication cost for container type 10 between Zone 8 and Zone 15: 12.56
# Communication cost for container type 11 between Zone 8 and Zone 15: 5.58
# Communication cost for container type 12 between Zone 8 and Zone 15: 12.84
# Communication cost for container type 13 between Zone 8 and Zone 15: 20.93
# Communication cost for container type 14 between Zone 8 and Zone 15: 12.84
# Communication cost for container type 15 between Zone 8 and Zone 15: 6.14
# Communication cost for container type 16 between Zone 8 and Zone 15: 5.86
# Communication cost for container type 17 between Zone 8 and Zone 15: 9.77
# Communication cost for container type 18 between Zone 8 and Zone 15: 7.81
# Communication cost for container type 19 between Zone 8 and Zone 15: 6.14
# Communication cost for container type 20 between Zone 8 and Zone 15: 6.42
# Communication cost for container type 21 between Zone 8 and Zone 15: 6.98
# Communication cost for container type 22 between Zone 8 and Zone 15: 6.42
# Communication cost for container type 23 between Zone 8 and Zone 15: 11.16
# Communication cost for container type 24 between Zone 8 and Zone 15: 7.53
# Communication cost for container type 25 between Zone 8 and Zone 15: 7.53
# Communication cost for container type 26 between Zone 8 and Zone 15: 16.18
# Communication cost for container type 27 between Zone 8 and Zone 15: 16.46
# Communication cost for container type 28 between Zone 8 and Zone 15: 6.42
# Communication cost for container type 29 between Zone 8 and Zone 15: 13.95
# Communication cost for container type 30 between Zone 8 and Zone 15: 8.37
# Communication cost for container type 31 between Zone 8 and Zone 15: 22.04
# Communication cost for container type 32 between Zone 8 and Zone 15: 25.11
# Communication cost for container type 33 between Zone 8 and Zone 15: 6.70
# Communication cost for container type 34 between Zone 8 and Zone 15: 46.32
# Communication cost for container type 35 between Zone 8 and Zone 15: 17.30
# Communication cost for container type 36 between Zone 8 and Zone 15: 53.29
# Communication cost for container type 37 between Zone 8 and Zone 15: 46.04
# Communication cost for container type 38 between Zone 8 and Zone 15: 47.44
# Communication cost for container type 39 between Zone 8 and Zone 15: 40.74
# Communication cost for container type 40 between Zone 8 and Zone 15: 24.83
# Communication cost for container type 41 between Zone 8 and Zone 15: 17.02
# Communication cost for container type 42 between Zone 8 and Zone 15: 7.25
# Communication cost for container type 43 between Zone 8 and Zone 15: 8.37
# Communication cost for container type 44 between Zone 8 and Zone 15: 23.72
# Communication cost for container type 45 between Zone 8 and Zone 15: 8.65
# Communication cost for container type 46 between Zone 8 and Zone 15: 13.11
# Communication cost for container type 47 between Zone 8 and Zone 15: 39.62
# Communication cost for container type 48 between Zone 8 and Zone 15: 13.11
# Communication cost for container type 49 between Zone 8 and Zone 15: 13.39
# Communication cost for container type 50 between Zone 8 and Zone 15: 69.76
# Communication cost for container type 1 between Zone 9 and Zone 1: 5.87
# Communication cost for container type 2 between Zone 9 and Zone 1: 5.87
# Communication cost for container type 3 between Zone 9 and Zone 1: 7.82
# Communication cost for container type 4 between Zone 9 and Zone 1: 5.59
# Communication cost for container type 5 between Zone 9 and Zone 1: 6.43
# Communication cost for container type 6 between Zone 9 and Zone 1: 5.87
# Communication cost for container type 7 between Zone 9 and Zone 1: 10.62
# Communication cost for container type 8 between Zone 9 and Zone 1: 6.15
# Communication cost for container type 9 between Zone 9 and Zone 1: 5.87
# Communication cost for container type 10 between Zone 9 and Zone 1: 12.57
# Communication cost for container type 11 between Zone 9 and Zone 1: 5.59
# Communication cost for container type 12 between Zone 9 and Zone 1: 12.85
# Communication cost for container type 13 between Zone 9 and Zone 1: 20.95
# Communication cost for container type 14 between Zone 9 and Zone 1: 12.85
# Communication cost for container type 15 between Zone 9 and Zone 1: 6.15
# Communication cost for container type 16 between Zone 9 and Zone 1: 5.87
# Communication cost for container type 17 between Zone 9 and Zone 1: 9.78
# Communication cost for container type 18 between Zone 9 and Zone 1: 7.82
# Communication cost for container type 19 between Zone 9 and Zone 1: 6.15
# Communication cost for container type 20 between Zone 9 and Zone 1: 6.43
# Communication cost for container type 21 between Zone 9 and Zone 1: 6.98
# Communication cost for container type 22 between Zone 9 and Zone 1: 6.43
# Communication cost for container type 23 between Zone 9 and Zone 1: 11.18
# Communication cost for container type 24 between Zone 9 and Zone 1: 7.54
# Communication cost for container type 25 between Zone 9 and Zone 1: 7.54
# Communication cost for container type 26 between Zone 9 and Zone 1: 16.20
# Communication cost for container type 27 between Zone 9 and Zone 1: 16.48
# Communication cost for container type 28 between Zone 9 and Zone 1: 6.43
# Communication cost for container type 29 between Zone 9 and Zone 1: 13.97
# Communication cost for container type 30 between Zone 9 and Zone 1: 8.38
# Communication cost for container type 31 between Zone 9 and Zone 1: 22.07
# Communication cost for container type 32 between Zone 9 and Zone 1: 25.15
# Communication cost for container type 33 between Zone 9 and Zone 1: 6.71
# Communication cost for container type 34 between Zone 9 and Zone 1: 46.38
# Communication cost for container type 35 between Zone 9 and Zone 1: 17.32
# Communication cost for container type 36 between Zone 9 and Zone 1: 53.36
# Communication cost for container type 37 between Zone 9 and Zone 1: 46.10
# Communication cost for container type 38 between Zone 9 and Zone 1: 47.50
# Communication cost for container type 39 between Zone 9 and Zone 1: 40.79
# Communication cost for container type 40 between Zone 9 and Zone 1: 24.87
# Communication cost for container type 41 between Zone 9 and Zone 1: 17.04
# Communication cost for container type 42 between Zone 9 and Zone 1: 7.26
# Communication cost for container type 43 between Zone 9 and Zone 1: 8.38
# Communication cost for container type 44 between Zone 9 and Zone 1: 23.75
# Communication cost for container type 45 between Zone 9 and Zone 1: 8.66
# Communication cost for container type 46 between Zone 9 and Zone 1: 13.13
# Communication cost for container type 47 between Zone 9 and Zone 1: 39.67
# Communication cost for container type 48 between Zone 9 and Zone 1: 13.13
# Communication cost for container type 49 between Zone 9 and Zone 1: 13.41
# Communication cost for container type 50 between Zone 9 and Zone 1: 69.85
# Communication cost for container type 1 between Zone 9 and Zone 2: 5.86
# Communication cost for container type 2 between Zone 9 and Zone 2: 5.86
# Communication cost for container type 3 between Zone 9 and Zone 2: 7.81
# Communication cost for container type 4 between Zone 9 and Zone 2: 5.58
# Communication cost for container type 5 between Zone 9 and Zone 2: 6.41
# Communication cost for container type 6 between Zone 9 and Zone 2: 5.86
# Communication cost for container type 7 between Zone 9 and Zone 2: 10.60
# Communication cost for container type 8 between Zone 9 and Zone 2: 6.13
# Communication cost for container type 9 between Zone 9 and Zone 2: 5.86
# Communication cost for container type 10 between Zone 9 and Zone 2: 12.55
# Communication cost for container type 11 between Zone 9 and Zone 2: 5.58
# Communication cost for container type 12 between Zone 9 and Zone 2: 12.83
# Communication cost for container type 13 between Zone 9 and Zone 2: 20.91
# Communication cost for container type 14 between Zone 9 and Zone 2: 12.83
# Communication cost for container type 15 between Zone 9 and Zone 2: 6.13
# Communication cost for container type 16 between Zone 9 and Zone 2: 5.86
# Communication cost for container type 17 between Zone 9 and Zone 2: 9.76
# Communication cost for container type 18 between Zone 9 and Zone 2: 7.81
# Communication cost for container type 19 between Zone 9 and Zone 2: 6.13
# Communication cost for container type 20 between Zone 9 and Zone 2: 6.41
# Communication cost for container type 21 between Zone 9 and Zone 2: 6.97
# Communication cost for container type 22 between Zone 9 and Zone 2: 6.41
# Communication cost for container type 23 between Zone 9 and Zone 2: 11.15
# Communication cost for container type 24 between Zone 9 and Zone 2: 7.53
# Communication cost for container type 25 between Zone 9 and Zone 2: 7.53
# Communication cost for container type 26 between Zone 9 and Zone 2: 16.17
# Communication cost for container type 27 between Zone 9 and Zone 2: 16.45
# Communication cost for container type 28 between Zone 9 and Zone 2: 6.41
# Communication cost for container type 29 between Zone 9 and Zone 2: 13.94
# Communication cost for container type 30 between Zone 9 and Zone 2: 8.37
# Communication cost for container type 31 between Zone 9 and Zone 2: 22.03
# Communication cost for container type 32 between Zone 9 and Zone 2: 25.10
# Communication cost for container type 33 between Zone 9 and Zone 2: 6.69
# Communication cost for container type 34 between Zone 9 and Zone 2: 46.29
# Communication cost for container type 35 between Zone 9 and Zone 2: 17.29
# Communication cost for container type 36 between Zone 9 and Zone 2: 53.26
# Communication cost for container type 37 between Zone 9 and Zone 2: 46.01
# Communication cost for container type 38 between Zone 9 and Zone 2: 47.40
# Communication cost for container type 39 between Zone 9 and Zone 2: 40.71
# Communication cost for container type 40 between Zone 9 and Zone 2: 24.82
# Communication cost for container type 41 between Zone 9 and Zone 2: 17.01
# Communication cost for container type 42 between Zone 9 and Zone 2: 7.25
# Communication cost for container type 43 between Zone 9 and Zone 2: 8.37
# Communication cost for container type 44 between Zone 9 and Zone 2: 23.70
# Communication cost for container type 45 between Zone 9 and Zone 2: 8.64
# Communication cost for container type 46 between Zone 9 and Zone 2: 13.11
# Communication cost for container type 47 between Zone 9 and Zone 2: 39.60
# Communication cost for container type 48 between Zone 9 and Zone 2: 13.11
# Communication cost for container type 49 between Zone 9 and Zone 2: 13.38
# Communication cost for container type 50 between Zone 9 and Zone 2: 69.71
# Communication cost for container type 1 between Zone 9 and Zone 3: 5.85
# Communication cost for container type 2 between Zone 9 and Zone 3: 5.85
# Communication cost for container type 3 between Zone 9 and Zone 3: 7.80
# Communication cost for container type 4 between Zone 9 and Zone 3: 5.57
# Communication cost for container type 5 between Zone 9 and Zone 3: 6.41
# Communication cost for container type 6 between Zone 9 and Zone 3: 5.85
# Communication cost for container type 7 between Zone 9 and Zone 3: 10.59
# Communication cost for container type 8 between Zone 9 and Zone 3: 6.13
# Communication cost for container type 9 between Zone 9 and Zone 3: 5.85
# Communication cost for container type 10 between Zone 9 and Zone 3: 12.54
# Communication cost for container type 11 between Zone 9 and Zone 3: 5.57
# Communication cost for container type 12 between Zone 9 and Zone 3: 12.82
# Communication cost for container type 13 between Zone 9 and Zone 3: 20.90
# Communication cost for container type 14 between Zone 9 and Zone 3: 12.82
# Communication cost for container type 15 between Zone 9 and Zone 3: 6.13
# Communication cost for container type 16 between Zone 9 and Zone 3: 5.85
# Communication cost for container type 17 between Zone 9 and Zone 3: 9.76
# Communication cost for container type 18 between Zone 9 and Zone 3: 7.80
# Communication cost for container type 19 between Zone 9 and Zone 3: 6.13
# Communication cost for container type 20 between Zone 9 and Zone 3: 6.41
# Communication cost for container type 21 between Zone 9 and Zone 3: 6.97
# Communication cost for container type 22 between Zone 9 and Zone 3: 6.41
# Communication cost for container type 23 between Zone 9 and Zone 3: 11.15
# Communication cost for container type 24 between Zone 9 and Zone 3: 7.53
# Communication cost for container type 25 between Zone 9 and Zone 3: 7.53
# Communication cost for container type 26 between Zone 9 and Zone 3: 16.17
# Communication cost for container type 27 between Zone 9 and Zone 3: 16.44
# Communication cost for container type 28 between Zone 9 and Zone 3: 6.41
# Communication cost for container type 29 between Zone 9 and Zone 3: 13.94
# Communication cost for container type 30 between Zone 9 and Zone 3: 8.36
# Communication cost for container type 31 between Zone 9 and Zone 3: 22.02
# Communication cost for container type 32 between Zone 9 and Zone 3: 25.09
# Communication cost for container type 33 between Zone 9 and Zone 3: 6.69
# Communication cost for container type 34 between Zone 9 and Zone 3: 46.27
# Communication cost for container type 35 between Zone 9 and Zone 3: 17.28
# Communication cost for container type 36 between Zone 9 and Zone 3: 53.24
# Communication cost for container type 37 between Zone 9 and Zone 3: 45.99
# Communication cost for container type 38 between Zone 9 and Zone 3: 47.38
# Communication cost for container type 39 between Zone 9 and Zone 3: 40.69
# Communication cost for container type 40 between Zone 9 and Zone 3: 24.81
# Communication cost for container type 41 between Zone 9 and Zone 3: 17.00
# Communication cost for container type 42 between Zone 9 and Zone 3: 7.25
# Communication cost for container type 43 between Zone 9 and Zone 3: 8.36
# Communication cost for container type 44 between Zone 9 and Zone 3: 23.69
# Communication cost for container type 45 between Zone 9 and Zone 3: 8.64
# Communication cost for container type 46 between Zone 9 and Zone 3: 13.10
# Communication cost for container type 47 between Zone 9 and Zone 3: 39.58
# Communication cost for container type 48 between Zone 9 and Zone 3: 13.10
# Communication cost for container type 49 between Zone 9 and Zone 3: 13.38
# Communication cost for container type 50 between Zone 9 and Zone 3: 69.68
# Communication cost for container type 1 between Zone 9 and Zone 4: 5.85
# Communication cost for container type 2 between Zone 9 and Zone 4: 5.85
# Communication cost for container type 3 between Zone 9 and Zone 4: 7.81
# Communication cost for container type 4 between Zone 9 and Zone 4: 5.58
# Communication cost for container type 5 between Zone 9 and Zone 4: 6.41
# Communication cost for container type 6 between Zone 9 and Zone 4: 5.85
# Communication cost for container type 7 between Zone 9 and Zone 4: 10.59
# Communication cost for container type 8 between Zone 9 and Zone 4: 6.13
# Communication cost for container type 9 between Zone 9 and Zone 4: 5.85
# Communication cost for container type 10 between Zone 9 and Zone 4: 12.55
# Communication cost for container type 11 between Zone 9 and Zone 4: 5.58
# Communication cost for container type 12 between Zone 9 and Zone 4: 12.82
# Communication cost for container type 13 between Zone 9 and Zone 4: 20.91
# Communication cost for container type 14 between Zone 9 and Zone 4: 12.82
# Communication cost for container type 15 between Zone 9 and Zone 4: 6.13
# Communication cost for container type 16 between Zone 9 and Zone 4: 5.85
# Communication cost for container type 17 between Zone 9 and Zone 4: 9.76
# Communication cost for container type 18 between Zone 9 and Zone 4: 7.81
# Communication cost for container type 19 between Zone 9 and Zone 4: 6.13
# Communication cost for container type 20 between Zone 9 and Zone 4: 6.41
# Communication cost for container type 21 between Zone 9 and Zone 4: 6.97
# Communication cost for container type 22 between Zone 9 and Zone 4: 6.41
# Communication cost for container type 23 between Zone 9 and Zone 4: 11.15
# Communication cost for container type 24 between Zone 9 and Zone 4: 7.53
# Communication cost for container type 25 between Zone 9 and Zone 4: 7.53
# Communication cost for container type 26 between Zone 9 and Zone 4: 16.17
# Communication cost for container type 27 between Zone 9 and Zone 4: 16.45
# Communication cost for container type 28 between Zone 9 and Zone 4: 6.41
# Communication cost for container type 29 between Zone 9 and Zone 4: 13.94
# Communication cost for container type 30 between Zone 9 and Zone 4: 8.36
# Communication cost for container type 31 between Zone 9 and Zone 4: 22.02
# Communication cost for container type 32 between Zone 9 and Zone 4: 25.09
# Communication cost for container type 33 between Zone 9 and Zone 4: 6.69
# Communication cost for container type 34 between Zone 9 and Zone 4: 46.28
# Communication cost for container type 35 between Zone 9 and Zone 4: 17.29
# Communication cost for container type 36 between Zone 9 and Zone 4: 53.25
# Communication cost for container type 37 between Zone 9 and Zone 4: 46.00
# Communication cost for container type 38 between Zone 9 and Zone 4: 47.40
# Communication cost for container type 39 between Zone 9 and Zone 4: 40.70
# Communication cost for container type 40 between Zone 9 and Zone 4: 24.81
# Communication cost for container type 41 between Zone 9 and Zone 4: 17.01
# Communication cost for container type 42 between Zone 9 and Zone 4: 7.25
# Communication cost for container type 43 between Zone 9 and Zone 4: 8.36
# Communication cost for container type 44 between Zone 9 and Zone 4: 23.70
# Communication cost for container type 45 between Zone 9 and Zone 4: 8.64
# Communication cost for container type 46 between Zone 9 and Zone 4: 13.10
# Communication cost for container type 47 between Zone 9 and Zone 4: 39.59
# Communication cost for container type 48 between Zone 9 and Zone 4: 13.10
# Communication cost for container type 49 between Zone 9 and Zone 4: 13.38
# Communication cost for container type 50 between Zone 9 and Zone 4: 69.70
# Communication cost for container type 1 between Zone 9 and Zone 5: 5.85
# Communication cost for container type 2 between Zone 9 and Zone 5: 5.85
# Communication cost for container type 3 between Zone 9 and Zone 5: 7.80
# Communication cost for container type 4 between Zone 9 and Zone 5: 5.57
# Communication cost for container type 5 between Zone 9 and Zone 5: 6.41
# Communication cost for container type 6 between Zone 9 and Zone 5: 5.85
# Communication cost for container type 7 between Zone 9 and Zone 5: 10.58
# Communication cost for container type 8 between Zone 9 and Zone 5: 6.13
# Communication cost for container type 9 between Zone 9 and Zone 5: 5.85
# Communication cost for container type 10 between Zone 9 and Zone 5: 12.53
# Communication cost for container type 11 between Zone 9 and Zone 5: 5.57
# Communication cost for container type 12 between Zone 9 and Zone 5: 12.81
# Communication cost for container type 13 between Zone 9 and Zone 5: 20.89
# Communication cost for container type 14 between Zone 9 and Zone 5: 12.81
# Communication cost for container type 15 between Zone 9 and Zone 5: 6.13
# Communication cost for container type 16 between Zone 9 and Zone 5: 5.85
# Communication cost for container type 17 between Zone 9 and Zone 5: 9.75
# Communication cost for container type 18 between Zone 9 and Zone 5: 7.80
# Communication cost for container type 19 between Zone 9 and Zone 5: 6.13
# Communication cost for container type 20 between Zone 9 and Zone 5: 6.41
# Communication cost for container type 21 between Zone 9 and Zone 5: 6.96
# Communication cost for container type 22 between Zone 9 and Zone 5: 6.41
# Communication cost for container type 23 between Zone 9 and Zone 5: 11.14
# Communication cost for container type 24 between Zone 9 and Zone 5: 7.52
# Communication cost for container type 25 between Zone 9 and Zone 5: 7.52
# Communication cost for container type 26 between Zone 9 and Zone 5: 16.16
# Communication cost for container type 27 between Zone 9 and Zone 5: 16.43
# Communication cost for container type 28 between Zone 9 and Zone 5: 6.41
# Communication cost for container type 29 between Zone 9 and Zone 5: 13.93
# Communication cost for container type 30 between Zone 9 and Zone 5: 8.36
# Communication cost for container type 31 between Zone 9 and Zone 5: 22.01
# Communication cost for container type 32 between Zone 9 and Zone 5: 25.07
# Communication cost for container type 33 between Zone 9 and Zone 5: 6.69
# Communication cost for container type 34 between Zone 9 and Zone 5: 46.24
# Communication cost for container type 35 between Zone 9 and Zone 5: 17.27
# Communication cost for container type 36 between Zone 9 and Zone 5: 53.20
# Communication cost for container type 37 between Zone 9 and Zone 5: 45.96
# Communication cost for container type 38 between Zone 9 and Zone 5: 47.35
# Communication cost for container type 39 between Zone 9 and Zone 5: 40.67
# Communication cost for container type 40 between Zone 9 and Zone 5: 24.79
# Communication cost for container type 41 between Zone 9 and Zone 5: 16.99
# Communication cost for container type 42 between Zone 9 and Zone 5: 7.24
# Communication cost for container type 43 between Zone 9 and Zone 5: 8.36
# Communication cost for container type 44 between Zone 9 and Zone 5: 23.68
# Communication cost for container type 45 between Zone 9 and Zone 5: 8.63
# Communication cost for container type 46 between Zone 9 and Zone 5: 13.09
# Communication cost for container type 47 between Zone 9 and Zone 5: 39.55
# Communication cost for container type 48 between Zone 9 and Zone 5: 13.09
# Communication cost for container type 49 between Zone 9 and Zone 5: 13.37
# Communication cost for container type 50 between Zone 9 and Zone 5: 69.64
# Communication cost for container type 1 between Zone 9 and Zone 6: 5.85
# Communication cost for container type 2 between Zone 9 and Zone 6: 5.85
# Communication cost for container type 3 between Zone 9 and Zone 6: 7.79
# Communication cost for container type 4 between Zone 9 and Zone 6: 5.57
# Communication cost for container type 5 between Zone 9 and Zone 6: 6.40
# Communication cost for container type 6 between Zone 9 and Zone 6: 5.85
# Communication cost for container type 7 between Zone 9 and Zone 6: 10.58
# Communication cost for container type 8 between Zone 9 and Zone 6: 6.12
# Communication cost for container type 9 between Zone 9 and Zone 6: 5.85
# Communication cost for container type 10 between Zone 9 and Zone 6: 12.53
# Communication cost for container type 11 between Zone 9 and Zone 6: 5.57
# Communication cost for container type 12 between Zone 9 and Zone 6: 12.81
# Communication cost for container type 13 between Zone 9 and Zone 6: 20.88
# Communication cost for container type 14 between Zone 9 and Zone 6: 12.81
# Communication cost for container type 15 between Zone 9 and Zone 6: 6.12
# Communication cost for container type 16 between Zone 9 and Zone 6: 5.85
# Communication cost for container type 17 between Zone 9 and Zone 6: 9.74
# Communication cost for container type 18 between Zone 9 and Zone 6: 7.79
# Communication cost for container type 19 between Zone 9 and Zone 6: 6.12
# Communication cost for container type 20 between Zone 9 and Zone 6: 6.40
# Communication cost for container type 21 between Zone 9 and Zone 6: 6.96
# Communication cost for container type 22 between Zone 9 and Zone 6: 6.40
# Communication cost for container type 23 between Zone 9 and Zone 6: 11.14
# Communication cost for container type 24 between Zone 9 and Zone 6: 7.52
# Communication cost for container type 25 between Zone 9 and Zone 6: 7.52
# Communication cost for container type 26 between Zone 9 and Zone 6: 16.15
# Communication cost for container type 27 between Zone 9 and Zone 6: 16.43
# Communication cost for container type 28 between Zone 9 and Zone 6: 6.40
# Communication cost for container type 29 between Zone 9 and Zone 6: 13.92
# Communication cost for container type 30 between Zone 9 and Zone 6: 8.35
# Communication cost for container type 31 between Zone 9 and Zone 6: 21.99
# Communication cost for container type 32 between Zone 9 and Zone 6: 25.06
# Communication cost for container type 33 between Zone 9 and Zone 6: 6.68
# Communication cost for container type 34 between Zone 9 and Zone 6: 46.21
# Communication cost for container type 35 between Zone 9 and Zone 6: 17.26
# Communication cost for container type 36 between Zone 9 and Zone 6: 53.17
# Communication cost for container type 37 between Zone 9 and Zone 6: 45.93
# Communication cost for container type 38 between Zone 9 and Zone 6: 47.33
# Communication cost for container type 39 between Zone 9 and Zone 6: 40.65
# Communication cost for container type 40 between Zone 9 and Zone 6: 24.78
# Communication cost for container type 41 between Zone 9 and Zone 6: 16.98
# Communication cost for container type 42 between Zone 9 and Zone 6: 7.24
# Communication cost for container type 43 between Zone 9 and Zone 6: 8.35
# Communication cost for container type 44 between Zone 9 and Zone 6: 23.66
# Communication cost for container type 45 between Zone 9 and Zone 6: 8.63
# Communication cost for container type 46 between Zone 9 and Zone 6: 13.08
# Communication cost for container type 47 between Zone 9 and Zone 6: 39.53
# Communication cost for container type 48 between Zone 9 and Zone 6: 13.08
# Communication cost for container type 49 between Zone 9 and Zone 6: 13.36
# Communication cost for container type 50 between Zone 9 and Zone 6: 69.60
# Communication cost for container type 1 between Zone 9 and Zone 7: 5.84
# Communication cost for container type 2 between Zone 9 and Zone 7: 5.84
# Communication cost for container type 3 between Zone 9 and Zone 7: 7.79
# Communication cost for container type 4 between Zone 9 and Zone 7: 5.57
# Communication cost for container type 5 between Zone 9 and Zone 7: 6.40
# Communication cost for container type 6 between Zone 9 and Zone 7: 5.84
# Communication cost for container type 7 between Zone 9 and Zone 7: 10.57
# Communication cost for container type 8 between Zone 9 and Zone 7: 6.12
# Communication cost for container type 9 between Zone 9 and Zone 7: 5.84
# Communication cost for container type 10 between Zone 9 and Zone 7: 12.52
# Communication cost for container type 11 between Zone 9 and Zone 7: 5.57
# Communication cost for container type 12 between Zone 9 and Zone 7: 12.80
# Communication cost for container type 13 between Zone 9 and Zone 7: 20.87
# Communication cost for container type 14 between Zone 9 and Zone 7: 12.80
# Communication cost for container type 15 between Zone 9 and Zone 7: 6.12
# Communication cost for container type 16 between Zone 9 and Zone 7: 5.84
# Communication cost for container type 17 between Zone 9 and Zone 7: 9.74
# Communication cost for container type 18 between Zone 9 and Zone 7: 7.79
# Communication cost for container type 19 between Zone 9 and Zone 7: 6.12
# Communication cost for container type 20 between Zone 9 and Zone 7: 6.40
# Communication cost for container type 21 between Zone 9 and Zone 7: 6.96
# Communication cost for container type 22 between Zone 9 and Zone 7: 6.40
# Communication cost for container type 23 between Zone 9 and Zone 7: 11.13
# Communication cost for container type 24 between Zone 9 and Zone 7: 7.51
# Communication cost for container type 25 between Zone 9 and Zone 7: 7.51
# Communication cost for container type 26 between Zone 9 and Zone 7: 16.14
# Communication cost for container type 27 between Zone 9 and Zone 7: 16.42
# Communication cost for container type 28 between Zone 9 and Zone 7: 6.40
# Communication cost for container type 29 between Zone 9 and Zone 7: 13.91
# Communication cost for container type 30 between Zone 9 and Zone 7: 8.35
# Communication cost for container type 31 between Zone 9 and Zone 7: 21.98
# Communication cost for container type 32 between Zone 9 and Zone 7: 25.04
# Communication cost for container type 33 between Zone 9 and Zone 7: 6.68
# Communication cost for container type 34 between Zone 9 and Zone 7: 46.19
# Communication cost for container type 35 between Zone 9 and Zone 7: 17.25
# Communication cost for container type 36 between Zone 9 and Zone 7: 53.15
# Communication cost for container type 37 between Zone 9 and Zone 7: 45.92
# Communication cost for container type 38 between Zone 9 and Zone 7: 47.31
# Communication cost for container type 39 between Zone 9 and Zone 7: 40.63
# Communication cost for container type 40 between Zone 9 and Zone 7: 24.77
# Communication cost for container type 41 between Zone 9 and Zone 7: 16.97
# Communication cost for container type 42 between Zone 9 and Zone 7: 7.24
# Communication cost for container type 43 between Zone 9 and Zone 7: 8.35
# Communication cost for container type 44 between Zone 9 and Zone 7: 23.65
# Communication cost for container type 45 between Zone 9 and Zone 7: 8.63
# Communication cost for container type 46 between Zone 9 and Zone 7: 13.08
# Communication cost for container type 47 between Zone 9 and Zone 7: 39.51
# Communication cost for container type 48 between Zone 9 and Zone 7: 13.08
# Communication cost for container type 49 between Zone 9 and Zone 7: 13.36
# Communication cost for container type 50 between Zone 9 and Zone 7: 69.57
# Communication cost for container type 1 between Zone 9 and Zone 8: 5.84
# Communication cost for container type 2 between Zone 9 and Zone 8: 5.84
# Communication cost for container type 3 between Zone 9 and Zone 8: 7.79
# Communication cost for container type 4 between Zone 9 and Zone 8: 5.57
# Communication cost for container type 5 between Zone 9 and Zone 8: 6.40
# Communication cost for container type 6 between Zone 9 and Zone 8: 5.84
# Communication cost for container type 7 between Zone 9 and Zone 8: 10.57
# Communication cost for container type 8 between Zone 9 and Zone 8: 6.12
# Communication cost for container type 9 between Zone 9 and Zone 8: 5.84
# Communication cost for container type 10 between Zone 9 and Zone 8: 12.52
# Communication cost for container type 11 between Zone 9 and Zone 8: 5.57
# Communication cost for container type 12 between Zone 9 and Zone 8: 12.80
# Communication cost for container type 13 between Zone 9 and Zone 8: 20.87
# Communication cost for container type 14 between Zone 9 and Zone 8: 12.80
# Communication cost for container type 15 between Zone 9 and Zone 8: 6.12
# Communication cost for container type 16 between Zone 9 and Zone 8: 5.84
# Communication cost for container type 17 between Zone 9 and Zone 8: 9.74
# Communication cost for container type 18 between Zone 9 and Zone 8: 7.79
# Communication cost for container type 19 between Zone 9 and Zone 8: 6.12
# Communication cost for container type 20 between Zone 9 and Zone 8: 6.40
# Communication cost for container type 21 between Zone 9 and Zone 8: 6.96
# Communication cost for container type 22 between Zone 9 and Zone 8: 6.40
# Communication cost for container type 23 between Zone 9 and Zone 8: 11.13
# Communication cost for container type 24 between Zone 9 and Zone 8: 7.51
# Communication cost for container type 25 between Zone 9 and Zone 8: 7.51
# Communication cost for container type 26 between Zone 9 and Zone 8: 16.14
# Communication cost for container type 27 between Zone 9 and Zone 8: 16.42
# Communication cost for container type 28 between Zone 9 and Zone 8: 6.40
# Communication cost for container type 29 between Zone 9 and Zone 8: 13.91
# Communication cost for container type 30 between Zone 9 and Zone 8: 8.35
# Communication cost for container type 31 between Zone 9 and Zone 8: 21.98
# Communication cost for container type 32 between Zone 9 and Zone 8: 25.04
# Communication cost for container type 33 between Zone 9 and Zone 8: 6.68
# Communication cost for container type 34 between Zone 9 and Zone 8: 46.19
# Communication cost for container type 35 between Zone 9 and Zone 8: 17.25
# Communication cost for container type 36 between Zone 9 and Zone 8: 53.15
# Communication cost for container type 37 between Zone 9 and Zone 8: 45.91
# Communication cost for container type 38 between Zone 9 and Zone 8: 47.30
# Communication cost for container type 39 between Zone 9 and Zone 8: 40.63
# Communication cost for container type 40 between Zone 9 and Zone 8: 24.77
# Communication cost for container type 41 between Zone 9 and Zone 8: 16.97
# Communication cost for container type 42 between Zone 9 and Zone 8: 7.23
# Communication cost for container type 43 between Zone 9 and Zone 8: 8.35
# Communication cost for container type 44 between Zone 9 and Zone 8: 23.65
# Communication cost for container type 45 between Zone 9 and Zone 8: 8.63
# Communication cost for container type 46 between Zone 9 and Zone 8: 13.08
# Communication cost for container type 47 between Zone 9 and Zone 8: 39.51
# Communication cost for container type 48 between Zone 9 and Zone 8: 13.08
# Communication cost for container type 49 between Zone 9 and Zone 8: 13.36
# Communication cost for container type 50 between Zone 9 and Zone 8: 69.56
# Communication cost for container type 1 between Zone 9 and Zone 10: 5.85
# Communication cost for container type 2 between Zone 9 and Zone 10: 5.85
# Communication cost for container type 3 between Zone 9 and Zone 10: 7.80
# Communication cost for container type 4 between Zone 9 and Zone 10: 5.57
# Communication cost for container type 5 between Zone 9 and Zone 10: 6.41
# Communication cost for container type 6 between Zone 9 and Zone 10: 5.85
# Communication cost for container type 7 between Zone 9 and Zone 10: 10.58
# Communication cost for container type 8 between Zone 9 and Zone 10: 6.13
# Communication cost for container type 9 between Zone 9 and Zone 10: 5.85
# Communication cost for container type 10 between Zone 9 and Zone 10: 12.53
# Communication cost for container type 11 between Zone 9 and Zone 10: 5.57
# Communication cost for container type 12 between Zone 9 and Zone 10: 12.81
# Communication cost for container type 13 between Zone 9 and Zone 10: 20.89
# Communication cost for container type 14 between Zone 9 and Zone 10: 12.81
# Communication cost for container type 15 between Zone 9 and Zone 10: 6.13
# Communication cost for container type 16 between Zone 9 and Zone 10: 5.85
# Communication cost for container type 17 between Zone 9 and Zone 10: 9.75
# Communication cost for container type 18 between Zone 9 and Zone 10: 7.80
# Communication cost for container type 19 between Zone 9 and Zone 10: 6.13
# Communication cost for container type 20 between Zone 9 and Zone 10: 6.41
# Communication cost for container type 21 between Zone 9 and Zone 10: 6.96
# Communication cost for container type 22 between Zone 9 and Zone 10: 6.41
# Communication cost for container type 23 between Zone 9 and Zone 10: 11.14
# Communication cost for container type 24 between Zone 9 and Zone 10: 7.52
# Communication cost for container type 25 between Zone 9 and Zone 10: 7.52
# Communication cost for container type 26 between Zone 9 and Zone 10: 16.15
# Communication cost for container type 27 between Zone 9 and Zone 10: 16.43
# Communication cost for container type 28 between Zone 9 and Zone 10: 6.41
# Communication cost for container type 29 between Zone 9 and Zone 10: 13.93
# Communication cost for container type 30 between Zone 9 and Zone 10: 8.36
# Communication cost for container type 31 between Zone 9 and Zone 10: 22.00
# Communication cost for container type 32 between Zone 9 and Zone 10: 25.07
# Communication cost for container type 33 between Zone 9 and Zone 10: 6.68
# Communication cost for container type 34 between Zone 9 and Zone 10: 46.23
# Communication cost for container type 35 between Zone 9 and Zone 10: 17.27
# Communication cost for container type 36 between Zone 9 and Zone 10: 53.19
# Communication cost for container type 37 between Zone 9 and Zone 10: 45.95
# Communication cost for container type 38 between Zone 9 and Zone 10: 47.35
# Communication cost for container type 39 between Zone 9 and Zone 10: 40.66
# Communication cost for container type 40 between Zone 9 and Zone 10: 24.79
# Communication cost for container type 41 between Zone 9 and Zone 10: 16.99
# Communication cost for container type 42 between Zone 9 and Zone 10: 7.24
# Communication cost for container type 43 between Zone 9 and Zone 10: 8.36
# Communication cost for container type 44 between Zone 9 and Zone 10: 23.67
# Communication cost for container type 45 between Zone 9 and Zone 10: 8.63
# Communication cost for container type 46 between Zone 9 and Zone 10: 13.09
# Communication cost for container type 47 between Zone 9 and Zone 10: 39.55
# Communication cost for container type 48 between Zone 9 and Zone 10: 13.09
# Communication cost for container type 49 between Zone 9 and Zone 10: 13.37
# Communication cost for container type 50 between Zone 9 and Zone 10: 69.63
# Communication cost for container type 1 between Zone 9 and Zone 11: 5.85
# Communication cost for container type 2 between Zone 9 and Zone 11: 5.85
# Communication cost for container type 3 between Zone 9 and Zone 11: 7.80
# Communication cost for container type 4 between Zone 9 and Zone 11: 5.57
# Communication cost for container type 5 between Zone 9 and Zone 11: 6.40
# Communication cost for container type 6 between Zone 9 and Zone 11: 5.85
# Communication cost for container type 7 between Zone 9 and Zone 11: 10.58
# Communication cost for container type 8 between Zone 9 and Zone 11: 6.13
# Communication cost for container type 9 between Zone 9 and Zone 11: 5.85
# Communication cost for container type 10 between Zone 9 and Zone 11: 12.53
# Communication cost for container type 11 between Zone 9 and Zone 11: 5.57
# Communication cost for container type 12 between Zone 9 and Zone 11: 12.81
# Communication cost for container type 13 between Zone 9 and Zone 11: 20.88
# Communication cost for container type 14 between Zone 9 and Zone 11: 12.81
# Communication cost for container type 15 between Zone 9 and Zone 11: 6.13
# Communication cost for container type 16 between Zone 9 and Zone 11: 5.85
# Communication cost for container type 17 between Zone 9 and Zone 11: 9.75
# Communication cost for container type 18 between Zone 9 and Zone 11: 7.80
# Communication cost for container type 19 between Zone 9 and Zone 11: 6.13
# Communication cost for container type 20 between Zone 9 and Zone 11: 6.40
# Communication cost for container type 21 between Zone 9 and Zone 11: 6.96
# Communication cost for container type 22 between Zone 9 and Zone 11: 6.40
# Communication cost for container type 23 between Zone 9 and Zone 11: 11.14
# Communication cost for container type 24 between Zone 9 and Zone 11: 7.52
# Communication cost for container type 25 between Zone 9 and Zone 11: 7.52
# Communication cost for container type 26 between Zone 9 and Zone 11: 16.15
# Communication cost for container type 27 between Zone 9 and Zone 11: 16.43
# Communication cost for container type 28 between Zone 9 and Zone 11: 6.40
# Communication cost for container type 29 between Zone 9 and Zone 11: 13.92
# Communication cost for container type 30 between Zone 9 and Zone 11: 8.35
# Communication cost for container type 31 between Zone 9 and Zone 11: 22.00
# Communication cost for container type 32 between Zone 9 and Zone 11: 25.06
# Communication cost for container type 33 between Zone 9 and Zone 11: 6.68
# Communication cost for container type 34 between Zone 9 and Zone 11: 46.22
# Communication cost for container type 35 between Zone 9 and Zone 11: 17.26
# Communication cost for container type 36 between Zone 9 and Zone 11: 53.18
# Communication cost for container type 37 between Zone 9 and Zone 11: 45.94
# Communication cost for container type 38 between Zone 9 and Zone 11: 47.33
# Communication cost for container type 39 between Zone 9 and Zone 11: 40.65
# Communication cost for container type 40 between Zone 9 and Zone 11: 24.78
# Communication cost for container type 41 between Zone 9 and Zone 11: 16.98
# Communication cost for container type 42 between Zone 9 and Zone 11: 7.24
# Communication cost for container type 43 between Zone 9 and Zone 11: 8.35
# Communication cost for container type 44 between Zone 9 and Zone 11: 23.67
# Communication cost for container type 45 between Zone 9 and Zone 11: 8.63
# Communication cost for container type 46 between Zone 9 and Zone 11: 13.09
# Communication cost for container type 47 between Zone 9 and Zone 11: 39.54
# Communication cost for container type 48 between Zone 9 and Zone 11: 13.09
# Communication cost for container type 49 between Zone 9 and Zone 11: 13.36
# Communication cost for container type 50 between Zone 9 and Zone 11: 69.61
# Communication cost for container type 1 between Zone 9 and Zone 12: 5.85
# Communication cost for container type 2 between Zone 9 and Zone 12: 5.85
# Communication cost for container type 3 between Zone 9 and Zone 12: 7.80
# Communication cost for container type 4 between Zone 9 and Zone 12: 5.57
# Communication cost for container type 5 between Zone 9 and Zone 12: 6.41
# Communication cost for container type 6 between Zone 9 and Zone 12: 5.85
# Communication cost for container type 7 between Zone 9 and Zone 12: 10.59
# Communication cost for container type 8 between Zone 9 and Zone 12: 6.13
# Communication cost for container type 9 between Zone 9 and Zone 12: 5.85
# Communication cost for container type 10 between Zone 9 and Zone 12: 12.54
# Communication cost for container type 11 between Zone 9 and Zone 12: 5.57
# Communication cost for container type 12 between Zone 9 and Zone 12: 12.82
# Communication cost for container type 13 between Zone 9 and Zone 12: 20.91
# Communication cost for container type 14 between Zone 9 and Zone 12: 12.82
# Communication cost for container type 15 between Zone 9 and Zone 12: 6.13
# Communication cost for container type 16 between Zone 9 and Zone 12: 5.85
# Communication cost for container type 17 between Zone 9 and Zone 12: 9.76
# Communication cost for container type 18 between Zone 9 and Zone 12: 7.80
# Communication cost for container type 19 between Zone 9 and Zone 12: 6.13
# Communication cost for container type 20 between Zone 9 and Zone 12: 6.41
# Communication cost for container type 21 between Zone 9 and Zone 12: 6.97
# Communication cost for container type 22 between Zone 9 and Zone 12: 6.41
# Communication cost for container type 23 between Zone 9 and Zone 12: 11.15
# Communication cost for container type 24 between Zone 9 and Zone 12: 7.53
# Communication cost for container type 25 between Zone 9 and Zone 12: 7.53
# Communication cost for container type 26 between Zone 9 and Zone 12: 16.17
# Communication cost for container type 27 between Zone 9 and Zone 12: 16.45
# Communication cost for container type 28 between Zone 9 and Zone 12: 6.41
# Communication cost for container type 29 between Zone 9 and Zone 12: 13.94
# Communication cost for container type 30 between Zone 9 and Zone 12: 8.36
# Communication cost for container type 31 between Zone 9 and Zone 12: 22.02
# Communication cost for container type 32 between Zone 9 and Zone 12: 25.09
# Communication cost for container type 33 between Zone 9 and Zone 12: 6.69
# Communication cost for container type 34 between Zone 9 and Zone 12: 46.27
# Communication cost for container type 35 between Zone 9 and Zone 12: 17.28
# Communication cost for container type 36 between Zone 9 and Zone 12: 53.24
# Communication cost for container type 37 between Zone 9 and Zone 12: 45.99
# Communication cost for container type 38 between Zone 9 and Zone 12: 47.39
# Communication cost for container type 39 between Zone 9 and Zone 12: 40.70
# Communication cost for container type 40 between Zone 9 and Zone 12: 24.81
# Communication cost for container type 41 between Zone 9 and Zone 12: 17.00
# Communication cost for container type 42 between Zone 9 and Zone 12: 7.25
# Communication cost for container type 43 between Zone 9 and Zone 12: 8.36
# Communication cost for container type 44 between Zone 9 and Zone 12: 23.69
# Communication cost for container type 45 between Zone 9 and Zone 12: 8.64
# Communication cost for container type 46 between Zone 9 and Zone 12: 13.10
# Communication cost for container type 47 between Zone 9 and Zone 12: 39.58
# Communication cost for container type 48 between Zone 9 and Zone 12: 13.10
# Communication cost for container type 49 between Zone 9 and Zone 12: 13.38
# Communication cost for container type 50 between Zone 9 and Zone 12: 69.69
# ...
# Communication cost for container type 39 between Zone 15 and Zone 10: 40.65
# Communication cost for container type 40 between Zone 15 and Zone 10: 24.78
# Communication cost for container type 41 between Zone 15 and Zone 10: 16.99
# Communication cost for container type 42 between Zone 15 and Zone 10: 7.24
# Communication cost for container type 43 between Zone 15 and Zone 10: 8.35
# Communication cost for container type 44 between Zone 15 and Zone 10: 23.67
# Communication cost for container type 45 between Zone 15 and Zone 10: 8.63
# Communication cost for container type 46 between Zone 15 and Zone 10: 13.09
# Communication cost for container type 47 between Zone 15 and Zone 10: 39.54
# Communication cost for container type 48 between Zone 15 and Zone 10: 13.09
# Communication cost for container type 49 between Zone 15 and Zone 10: 13.37
# Communication cost for container type 50 between Zone 15 and Zone 10: 69.61
# Communication cost for container type 1 between Zone 15 and Zone 11: 5.85
# Communication cost for container type 2 between Zone 15 and Zone 11: 5.85
# Communication cost for container type 3 between Zone 15 and Zone 11: 7.80
# Communication cost for container type 4 between Zone 15 and Zone 11: 5.57
# Communication cost for container type 5 between Zone 15 and Zone 11: 6.41
# Communication cost for container type 6 between Zone 15 and Zone 11: 5.85
# Communication cost for container type 7 between Zone 15 and Zone 11: 10.59
# Communication cost for container type 8 between Zone 15 and Zone 11: 6.13
# Communication cost for container type 9 between Zone 15 and Zone 11: 5.85
# Communication cost for container type 10 between Zone 15 and Zone 11: 12.54
# Communication cost for container type 11 between Zone 15 and Zone 11: 5.57
# Communication cost for container type 12 between Zone 15 and Zone 11: 12.81
# Communication cost for container type 13 between Zone 15 and Zone 11: 20.89
# Communication cost for container type 14 between Zone 15 and Zone 11: 12.81
# Communication cost for container type 15 between Zone 15 and Zone 11: 6.13
# Communication cost for container type 16 between Zone 15 and Zone 11: 5.85
# Communication cost for container type 17 between Zone 15 and Zone 11: 9.75
# Communication cost for container type 18 between Zone 15 and Zone 11: 7.80
# Communication cost for container type 19 between Zone 15 and Zone 11: 6.13
# Communication cost for container type 20 between Zone 15 and Zone 11: 6.41
# Communication cost for container type 21 between Zone 15 and Zone 11: 6.96
# Communication cost for container type 22 between Zone 15 and Zone 11: 6.41
# Communication cost for container type 23 between Zone 15 and Zone 11: 11.14
# Communication cost for container type 24 between Zone 15 and Zone 11: 7.52
# Communication cost for container type 25 between Zone 15 and Zone 11: 7.52
# Communication cost for container type 26 between Zone 15 and Zone 11: 16.16
# Communication cost for container type 27 between Zone 15 and Zone 11: 16.44
# Communication cost for container type 28 between Zone 15 and Zone 11: 6.41
# Communication cost for container type 29 between Zone 15 and Zone 11: 13.93
# Communication cost for container type 30 between Zone 15 and Zone 11: 8.36
# Communication cost for container type 31 between Zone 15 and Zone 11: 22.01
# Communication cost for container type 32 between Zone 15 and Zone 11: 25.07
# Communication cost for container type 33 between Zone 15 and Zone 11: 6.69
# Communication cost for container type 34 between Zone 15 and Zone 11: 46.25
# Communication cost for container type 35 between Zone 15 and Zone 11: 17.27
# Communication cost for container type 36 between Zone 15 and Zone 11: 53.21
# Communication cost for container type 37 between Zone 15 and Zone 11: 45.97
# Communication cost for container type 38 between Zone 15 and Zone 11: 47.36
# Communication cost for container type 39 between Zone 15 and Zone 11: 40.67
# Communication cost for container type 40 between Zone 15 and Zone 11: 24.79
# Communication cost for container type 41 between Zone 15 and Zone 11: 16.99
# Communication cost for container type 42 between Zone 15 and Zone 11: 7.24
# Communication cost for container type 43 between Zone 15 and Zone 11: 8.36
# Communication cost for container type 44 between Zone 15 and Zone 11: 23.68
# Communication cost for container type 45 between Zone 15 and Zone 11: 8.64
# Communication cost for container type 46 between Zone 15 and Zone 11: 13.09
# Communication cost for container type 47 between Zone 15 and Zone 11: 39.56
# Communication cost for container type 48 between Zone 15 and Zone 11: 13.09
# Communication cost for container type 49 between Zone 15 and Zone 11: 13.37
# Communication cost for container type 50 between Zone 15 and Zone 11: 69.65
# Communication cost for container type 1 between Zone 15 and Zone 12: 5.84
# Communication cost for container type 2 between Zone 15 and Zone 12: 5.84
# Communication cost for container type 3 between Zone 15 and Zone 12: 7.79
# Communication cost for container type 4 between Zone 15 and Zone 12: 5.57
# Communication cost for container type 5 between Zone 15 and Zone 12: 6.40
# Communication cost for container type 6 between Zone 15 and Zone 12: 5.84
# Communication cost for container type 7 between Zone 15 and Zone 12: 10.58
# Communication cost for container type 8 between Zone 15 and Zone 12: 6.12
# Communication cost for container type 9 between Zone 15 and Zone 12: 5.84
# Communication cost for container type 10 between Zone 15 and Zone 12: 12.52
# Communication cost for container type 11 between Zone 15 and Zone 12: 5.57
# Communication cost for container type 12 between Zone 15 and Zone 12: 12.80
# Communication cost for container type 13 between Zone 15 and Zone 12: 20.87
# Communication cost for container type 14 between Zone 15 and Zone 12: 12.80
# Communication cost for container type 15 between Zone 15 and Zone 12: 6.12
# Communication cost for container type 16 between Zone 15 and Zone 12: 5.84
# Communication cost for container type 17 between Zone 15 and Zone 12: 9.74
# Communication cost for container type 18 between Zone 15 and Zone 12: 7.79
# Communication cost for container type 19 between Zone 15 and Zone 12: 6.12
# Communication cost for container type 20 between Zone 15 and Zone 12: 6.40
# Communication cost for container type 21 between Zone 15 and Zone 12: 6.96
# Communication cost for container type 22 between Zone 15 and Zone 12: 6.40
# Communication cost for container type 23 between Zone 15 and Zone 12: 11.13
# Communication cost for container type 24 between Zone 15 and Zone 12: 7.51
# Communication cost for container type 25 between Zone 15 and Zone 12: 7.51
# Communication cost for container type 26 between Zone 15 and Zone 12: 16.14
# Communication cost for container type 27 between Zone 15 and Zone 12: 16.42
# Communication cost for container type 28 between Zone 15 and Zone 12: 6.40
# Communication cost for container type 29 between Zone 15 and Zone 12: 13.92
# Communication cost for container type 30 between Zone 15 and Zone 12: 8.35
# Communication cost for container type 31 between Zone 15 and Zone 12: 21.99
# Communication cost for container type 32 between Zone 15 and Zone 12: 25.05
# Communication cost for container type 33 between Zone 15 and Zone 12: 6.68
# Communication cost for container type 34 between Zone 15 and Zone 12: 46.20
# Communication cost for container type 35 between Zone 15 and Zone 12: 17.26
# Communication cost for container type 36 between Zone 15 and Zone 12: 53.16
# Communication cost for container type 37 between Zone 15 and Zone 12: 45.92
# Communication cost for container type 38 between Zone 15 and Zone 12: 47.31
# Communication cost for container type 39 between Zone 15 and Zone 12: 40.64
# Communication cost for container type 40 between Zone 15 and Zone 12: 24.77
# Communication cost for container type 41 between Zone 15 and Zone 12: 16.98
# Communication cost for container type 42 between Zone 15 and Zone 12: 7.24
# Communication cost for container type 43 between Zone 15 and Zone 12: 8.35
# Communication cost for container type 44 between Zone 15 and Zone 12: 23.66
# Communication cost for container type 45 between Zone 15 and Zone 12: 8.63
# Communication cost for container type 46 between Zone 15 and Zone 12: 13.08
# Communication cost for container type 47 between Zone 15 and Zone 12: 39.52
# Communication cost for container type 48 between Zone 15 and Zone 12: 13.08
# Communication cost for container type 49 between Zone 15 and Zone 12: 13.36
# Communication cost for container type 50 between Zone 15 and Zone 12: 69.58
# Communication cost for container type 1 between Zone 15 and Zone 13: 5.85
# Communication cost for container type 2 between Zone 15 and Zone 13: 5.85
# Communication cost for container type 3 between Zone 15 and Zone 13: 7.80
# Communication cost for container type 4 between Zone 15 and Zone 13: 5.57
# Communication cost for container type 5 between Zone 15 and Zone 13: 6.40
# Communication cost for container type 6 between Zone 15 and Zone 13: 5.85
# Communication cost for container type 7 between Zone 15 and Zone 13: 10.58
# Communication cost for container type 8 between Zone 15 and Zone 13: 6.13
# Communication cost for container type 9 between Zone 15 and Zone 13: 5.85
# Communication cost for container type 10 between Zone 15 and Zone 13: 12.53
# Communication cost for container type 11 between Zone 15 and Zone 13: 5.57
# Communication cost for container type 12 between Zone 15 and Zone 13: 12.81
# Communication cost for container type 13 between Zone 15 and Zone 13: 20.88
# Communication cost for container type 14 between Zone 15 and Zone 13: 12.81
# Communication cost for container type 15 between Zone 15 and Zone 13: 6.13
# Communication cost for container type 16 between Zone 15 and Zone 13: 5.85
# Communication cost for container type 17 between Zone 15 and Zone 13: 9.75
# Communication cost for container type 18 between Zone 15 and Zone 13: 7.80
# Communication cost for container type 19 between Zone 15 and Zone 13: 6.13
# Communication cost for container type 20 between Zone 15 and Zone 13: 6.40
# Communication cost for container type 21 between Zone 15 and Zone 13: 6.96
# Communication cost for container type 22 between Zone 15 and Zone 13: 6.40
# Communication cost for container type 23 between Zone 15 and Zone 13: 11.14
# Communication cost for container type 24 between Zone 15 and Zone 13: 7.52
# Communication cost for container type 25 between Zone 15 and Zone 13: 7.52
# Communication cost for container type 26 between Zone 15 and Zone 13: 16.15
# Communication cost for container type 27 between Zone 15 and Zone 13: 16.43
# Communication cost for container type 28 between Zone 15 and Zone 13: 6.40
# Communication cost for container type 29 between Zone 15 and Zone 13: 13.92
# Communication cost for container type 30 between Zone 15 and Zone 13: 8.35
# Communication cost for container type 31 between Zone 15 and Zone 13: 22.00
# Communication cost for container type 32 between Zone 15 and Zone 13: 25.06
# Communication cost for container type 33 between Zone 15 and Zone 13: 6.68
# Communication cost for container type 34 between Zone 15 and Zone 13: 46.23
# Communication cost for container type 35 between Zone 15 and Zone 13: 17.26
# Communication cost for container type 36 between Zone 15 and Zone 13: 53.19
# Communication cost for container type 37 between Zone 15 and Zone 13: 45.95
# Communication cost for container type 38 between Zone 15 and Zone 13: 47.34
# Communication cost for container type 39 between Zone 15 and Zone 13: 40.66
# Communication cost for container type 40 between Zone 15 and Zone 13: 24.78
# Communication cost for container type 41 between Zone 15 and Zone 13: 16.99
# Communication cost for container type 42 between Zone 15 and Zone 13: 7.24
# Communication cost for container type 43 between Zone 15 and Zone 13: 8.35
# Communication cost for container type 44 between Zone 15 and Zone 13: 23.67
# Communication cost for container type 45 between Zone 15 and Zone 13: 8.63
# Communication cost for container type 46 between Zone 15 and Zone 13: 13.09
# Communication cost for container type 47 between Zone 15 and Zone 13: 39.54
# Communication cost for container type 48 between Zone 15 and Zone 13: 13.09
# Communication cost for container type 49 between Zone 15 and Zone 13: 13.37
# Communication cost for container type 50 between Zone 15 and Zone 13: 69.62
# Communication cost for container type 1 between Zone 15 and Zone 14: 5.84
# Communication cost for container type 2 between Zone 15 and Zone 14: 5.84
# Communication cost for container type 3 between Zone 15 and Zone 14: 7.79
# Communication cost for container type 4 between Zone 15 and Zone 14: 5.56
# Communication cost for container type 5 between Zone 15 and Zone 14: 6.40
# Communication cost for container type 6 between Zone 15 and Zone 14: 5.84
# Communication cost for container type 7 between Zone 15 and Zone 14: 10.57
# Communication cost for container type 8 between Zone 15 and Zone 14: 6.12
# Communication cost for container type 9 between Zone 15 and Zone 14: 5.84
# Communication cost for container type 10 between Zone 15 and Zone 14: 12.52
# Communication cost for container type 11 between Zone 15 and Zone 14: 5.56
# Communication cost for container type 12 between Zone 15 and Zone 14: 12.79
# Communication cost for container type 13 between Zone 15 and Zone 14: 20.86
# Communication cost for container type 14 between Zone 15 and Zone 14: 12.79
# Communication cost for container type 15 between Zone 15 and Zone 14: 6.12
# Communication cost for container type 16 between Zone 15 and Zone 14: 5.84
# Communication cost for container type 17 between Zone 15 and Zone 14: 9.73
# Communication cost for container type 18 between Zone 15 and Zone 14: 7.79
# Communication cost for container type 19 between Zone 15 and Zone 14: 6.12
# Communication cost for container type 20 between Zone 15 and Zone 14: 6.40
# Communication cost for container type 21 between Zone 15 and Zone 14: 6.95
# Communication cost for container type 22 between Zone 15 and Zone 14: 6.40
# Communication cost for container type 23 between Zone 15 and Zone 14: 11.12
# Communication cost for container type 24 between Zone 15 and Zone 14: 7.51
# Communication cost for container type 25 between Zone 15 and Zone 14: 7.51
# Communication cost for container type 26 between Zone 15 and Zone 14: 16.13
# Communication cost for container type 27 between Zone 15 and Zone 14: 16.41
# Communication cost for container type 28 between Zone 15 and Zone 14: 6.40
# Communication cost for container type 29 between Zone 15 and Zone 14: 13.91
# Communication cost for container type 30 between Zone 15 and Zone 14: 8.34
# Communication cost for container type 31 between Zone 15 and Zone 14: 21.97
# Communication cost for container type 32 between Zone 15 and Zone 14: 25.03
# Communication cost for container type 33 between Zone 15 and Zone 14: 6.67
# Communication cost for container type 34 between Zone 15 and Zone 14: 46.17
# Communication cost for container type 35 between Zone 15 and Zone 14: 17.24
# Communication cost for container type 36 between Zone 15 and Zone 14: 53.12
# Communication cost for container type 37 between Zone 15 and Zone 14: 45.89
# Communication cost for container type 38 between Zone 15 and Zone 14: 47.28
# Communication cost for container type 39 between Zone 15 and Zone 14: 40.60
# Communication cost for container type 40 between Zone 15 and Zone 14: 24.75
# Communication cost for container type 41 between Zone 15 and Zone 14: 16.96
# Communication cost for container type 42 between Zone 15 and Zone 14: 7.23
# Communication cost for container type 43 between Zone 15 and Zone 14: 8.34
# Communication cost for container type 44 between Zone 15 and Zone 14: 23.64
# Communication cost for container type 45 between Zone 15 and Zone 14: 8.62
# Communication cost for container type 46 between Zone 15 and Zone 14: 13.07
# Communication cost for container type 47 between Zone 15 and Zone 14: 39.49
# Communication cost for container type 48 between Zone 15 and Zone 14: 13.07
# Communication cost for container type 49 between Zone 15 and Zone 14: 13.35
# Communication cost for container type 50 between Zone 15 and Zone 14: 69.53

# %%
def initialize_cache(zones, max_requests_per_zone, ranked_functions, instantiation_costs):
    CR_I_0 = 0  # Chi phí khởi tạo tại t = 0

    for z, zone in zones.items():
        for node in zone.nodes:
            for k in max_requests_per_zone[z]:
                half_max_requests = max_requests_per_zone[z][k] // 4
                size = ranked_functions[k][2]
                for _ in range(half_max_requests):
                    request = Request(user_id=node.site_id, request_type=k, size=size, timestamp=0)
                    node.store_request(request, remaining_time=100, current_time_slot=0)  # Assume initial remaining time is 100
                    CR_I_0 += zone.instantiation_costs[(node.site_id, k)]  # Cộng thêm chi phí khởi tạo
                # print(f"Initialized {half_max_requests} containers for request type {k} at node {node.site_id} in zone {z}")

    return CR_I_0

# %%
def WQ_algorithm(zones, K, total_time_slots, lambda_n_k_t, communication_costs, alpha):
    CL = [0] * total_time_slots  # Chi phí truyền thông
    CR_I = [0] * total_time_slots  # Chi phí khởi tạo
    CR_R = [0] * total_time_slots  # Chi phí lưu trữ

    # Tính toán số lượng request lớn nhất
    max_requests_per_zone = find_max_requests_per_node_per_zone(lambda_n_k_t)

    # Khởi tạo ban đầu tại time-slot 0 và tính chi phí khởi tạo
    CR_I[0] = initialize_cache(zones, max_requests_per_zone, ranked_functions, zones[1].instantiation_costs)

    for t in range(total_time_slots):
        print(f"\n--- Time-slot {t} ---")

        # Cập nhật cache cho tất cả các node vào đầu mỗi time-slot
        for z, zone in zones.items():
            for node in zone.nodes:
                node.update_cache(current_time_slot=t)

        if t == 0:
            # Phân bổ và xử lý request tại time-slot 0
            for z, zone in zones.items():
                for k in range(1, K + 1):
                    for node in zone.nodes:
                        num_requests = lambda_n_k_t.get((z, node.site_id, k, t), 0)
                        for _ in range(num_requests):
                            request = Request(user_id=node.site_id, request_type=k, size=ranked_functions[k][2], timestamp=t)
                            if node.cache[t] is not None:
                                entry = next((entry for entry in node.cache[t] if entry.request.request_type == k and entry.state == "stored"), None)
                            else:
                                entry = None

                            if entry:
                                entry.state = "served"
                            else:
                                if node.can_store_container(request.size):
                                    node.store_request(request, remaining_time=100, current_time_slot=t)
                                else:
                                    # Loại bỏ các container đầu hàng đợi cho đến khi node có thể lưu container mới
                                    while not node.can_store_container(request.size) and node.cache[t]:
                                        node.pop_container(t)
                                    if node.can_store_container(request.size):
                                        node.store_request(request, remaining_time=100, current_time_slot=t)
                                        CR_I[t] += zone.instantiation_costs[(node.site_id, k)]
                                    else:
                                        print(f"Không thể lưu request {request} tại node {node.site_id} ở zone {z} trong time-slot {t}")
        else:
            # Phân bổ và xử lý request từ time-slot 1 trở đi
            for z, zone in zones.items():
                for k in range(1, K + 1):
                    lambda_k_t = sum(lambda_n_k_t.get((z, node.site_id, k, t), 0) for node in zone.nodes)

                    # Phân bổ ngẫu nhiên request vào từng node
                    for node in zone.nodes:
                        num_requests = lambda_n_k_t.get((z, node.site_id, k, t), 0)
                        requests = [Request(user_id=node.site_id, request_type=k, size=ranked_functions[k][2], timestamp=t) for _ in range(num_requests)]
                        random.shuffle(requests)
                        node.queue[t].extend(requests)

                    # Xử lý các request trong queue của từng node theo FIFO
                    for node in zone.nodes:
                        while node.queue[t]:
                            request = node.queue[t].pop(0)
                            if node.cache[t] is not None:
                                entry = next((entry for entry in node.cache[t] if entry.request.request_type == request.request_type and entry.state == "stored"), None)
                            else:
                                entry = None

                            if entry:
                                entry.state = "served"
                                CR_R[t] += alpha * zone.retention_costs[(node.site_id, k)]
                            else:
                                if node.can_store_container(request.size):
                                    remaining_time = 100
                                    node.store_request(request, remaining_time, current_time_slot=t)
                                    CR_I[t] += zone.instantiation_costs[(node.site_id, k)]
                                else:
                                    # Loại bỏ các container đầu hàng đợi cho đến khi node có thể lưu container mới
                                    while not node.can_store_container(request.size) and node.cache[t]:
                                        node.pop_container(t)
                                    if node.can_store_container(request.size):
                                        remaining_time = 100
                                        node.store_request(request, remaining_time, current_time_slot=t)
                                        CR_I[t] += zone.instantiation_costs[(node.site_id, k)]
                                    else:
                                        print(f"Không thể lưu request {request} tại node {node.site_id} ở zone {z} trong time-slot {t}")

            for z, zone in zones.items():
                for node in zone.nodes:
                    if node.cache[t] is not None:
                        for entry in node.cache[t]:
                            if entry.state == "stored":
                                CR_R[t] += alpha * zone.retention_costs[(node.site_id, entry.request.request_type)]  # Thêm chi phí lưu trữ cho container rảnh

        # Hiển thị chi phí tại mỗi time-slot
        print(f"Chi phí truyền thông tại time-slot {t}: {CL[t]}")
        print(f"Chi phí lưu trữ tại time-slot {t}: {CR_R[t]}")
        print(f"Chi phí khởi tạo tại time-slot {t}: {CR_I[t]}")

        # # Hiển thị cache của từng node
        # for z, zone in zones.items():
        #     print(f"Zone {z}:")
        #     for node in zone.nodes:
        #         print(f"  Node {node.site_id} Cache at time-slot {t}:")
        #         if node.cache[t]:
        #             for entry in node.cache[t]:
        #                 print(f"    Request: {entry.request}, Remaining Time: {entry.remaining_time}, State: {entry.state}")
        #         else:
        #             print("    Cache is empty")

    # Tính tổng chi phí
    total_CL = sum(CL)
    total_CR_R = sum(CR_R)
    total_CR_I = sum(CR_I)
    total_CR = total_CR_R + total_CR_I
    print(f"Tổng chi phí truyền thông: {total_CL}")
    print(f"Tổng chi phí lưu trữ: {total_CR_R}")
    print(f"Tổng chi phí khởi tạo: {total_CR_I}")
    print(f"Tổng chi phí lưu trữ và khởi tạo: {total_CR}")

    return CL, CR_R, CR_I

# %%
import sys

# Redirect print statements to a file
class Logger(object):
    def __init__(self, filename="Default.log"):
        self.terminal = sys.stdout
        self.log = open(filename, "w")

    def write(self, message):
        self.terminal.write(message)
        self.log.write(message)

    def flush(self):
        pass

sys.stdout = Logger("output_WQ_b=1.5_a=0.01_20xuser.txt")

# Thực hiện tính toán ORDC và in kết quả
WQ_algorithm(zones, K, 100, lambda_n_k_t, communication_costs, alpha)


# Đặt lại stdout về chế độ ban đầu
sys.stdout = sys.__stdout__

print("Kết quả đã được lưu vào file output.txt")
# Out:
# --- Time-slot 0 ---
# Chi phí truyền thông tại time-slot 0: 0
# Chi phí lưu trữ tại time-slot 0: 0
# Chi phí khởi tạo tại time-slot 0: 137532.0673400675
#
# --- Time-slot 1 ---
# Chi phí truyền thông tại time-slot 1: 0
# Chi phí lưu trữ tại time-slot 1: 12663.830999999587
# Chi phí khởi tạo tại time-slot 1: 40666.580808080995
#
# --- Time-slot 2 ---
# Chi phí truyền thông tại time-slot 2: 0
# Chi phí lưu trữ tại time-slot 2: 16012.43099999898
# Chi phí khởi tạo tại time-slot 2: 28169.02356902345
#
# --- Time-slot 3 ---
# Chi phí truyền thông tại time-slot 3: 0
# Chi phí lưu trữ tại time-slot 3: 17884.787999998985
# Chi phí khởi tạo tại time-slot 3: 24332.613636363563
#
# --- Time-slot 4 ---
# Chi phí truyền thông tại time-slot 4: 0
# Chi phí lưu trữ tại time-slot 4: 19689.17999999888
# Chi phí khởi tạo tại time-slot 4: 18403.539562289534
#
# --- Time-slot 5 ---
# Chi phí truyền thông tại time-slot 5: 0
# Chi phí lưu trữ tại time-slot 5: 20696.321999998923
# Chi phí khởi tạo tại time-slot 5: 17934.818181818126
#
# --- Time-slot 6 ---
# Chi phí truyền thông tại time-slot 6: 0
# Chi phí lưu trữ tại time-slot 6: 21810.242999998845
# Chi phí khởi tạo tại time-slot 6: 14655.551346801278
#
# --- Time-slot 7 ---
# Chi phí truyền thông tại time-slot 7: 0
# Chi phí lưu trữ tại time-slot 7: 22419.920999998925
# Chi phí khởi tạo tại time-slot 7: 15630.16498316487
#
# --- Time-slot 8 ---
# Chi phí truyền thông tại time-slot 8: 0
# Chi phí lưu trữ tại time-slot 8: 23320.57799999918
# Chi phí khởi tạo tại time-slot 8: 12299.593434343398
#
# --- Time-slot 9 ---
# Chi phí truyền thông tại time-slot 9: 0
# Chi phí lưu trữ tại time-slot 9: 23813.84699999909
# Chi phí khởi tạo tại time-slot 9: 12485.626262626245
#
# --- Time-slot 10 ---
# Chi phí truyền thông tại time-slot 10: 0
# Chi phí lưu trữ tại time-slot 10: 24530.663999999233
# Chi phí khởi tạo tại time-slot 10: 10380.881313131273
#
# --- Time-slot 11 ---
# Chi phí truyền thông tại time-slot 11: 0
# Chi phí lưu trữ tại time-slot 11: 24858.863999999223
# Chi phí khởi tạo tại time-slot 11: 11021.259259259215
#
# --- Time-slot 12 ---
# Chi phí truyền thông tại time-slot 12: 0
# Chi phí lưu trữ tại time-slot 12: 25373.96099999934
# Chi phí khởi tạo tại time-slot 12: 10504.513468013456
#
# --- Time-slot 13 ---
# Chi phí truyền thông tại time-slot 13: 0
# Chi phí lưu trữ tại time-slot 13: 25770.48899999916
# Chi phí khởi tạo tại time-slot 13: 10787.570707070658
#
# --- Time-slot 14 ---
# Chi phí truyền thông tại time-slot 14: 0
# Chi phí lưu trữ tại time-slot 14: 26256.82799999918
# Chi phí khởi tạo tại time-slot 14: 10118.597643097637
#
# --- Time-slot 15 ---
# Chi phí truyền thông tại time-slot 15: 0
# Chi phí lưu trữ tại time-slot 15: 26558.915999999313
# Chi phí khởi tạo tại time-slot 15: 10001.013468013427
#
# --- Time-slot 16 ---
# Chi phí truyền thông tại time-slot 16: 0
# Chi phí lưu trữ tại time-slot 16: 27003.572999999247
# Chi phí khởi tạo tại time-slot 16: 7864.193602693578
#
# --- Time-slot 17 ---
# Chi phí truyền thông tại time-slot 17: 0
# Chi phí lưu trữ tại time-slot 17: 27226.286999999207
# Chi phí khởi tạo tại time-slot 17: 7828.98905723901
#
# --- Time-slot 18 ---
# Chi phí truyền thông tại time-slot 18: 0
# Chi phí lưu trữ tại time-slot 18: 27374.49299999939
# Chi phí khởi tạo tại time-slot 18: 9609.5976430976
#
# --- Time-slot 19 ---
# Chi phí truyền thông tại time-slot 19: 0
# Chi phí lưu trữ tại time-slot 19: 27769.421999999264
# Chi phí khởi tạo tại time-slot 19: 8632.094276094253
#
# --- Time-slot 20 ---
# Chi phí truyền thông tại time-slot 20: 0
# Chi phí lưu trữ tại time-slot 20: 28167.236999999288
# Chi phí khởi tạo tại time-slot 20: 6471.845117845116
#
# --- Time-slot 21 ---
# Chi phí truyền thông tại time-slot 21: 0
# Chi phí lưu trữ tại time-slot 21: 28387.48199999913
# Chi phí khởi tạo tại time-slot 21: 7147.1085858585775
#
# --- Time-slot 22 ---
# Chi phí truyền thông tại time-slot 22: 0
# Chi phí lưu trữ tại time-slot 22: 28463.26499999927
# Chi phí khởi tạo tại time-slot 22: 9219.786195286184
#
# --- Time-slot 23 ---
# Chi phí truyền thông tại time-slot 23: 0
# Chi phí lưu trữ tại time-slot 23: 28740.917999999307
# Chi phí khởi tạo tại time-slot 23: 8404.347643097633
#
# --- Time-slot 24 ---
# Chi phí truyền thông tại time-slot 24: 0
# Chi phí lưu trữ tại time-slot 24: 28943.94899999937
# Chi phí khởi tạo tại time-slot 24: 9196.523569023551
#
# --- Time-slot 25 ---
# Chi phí truyền thông tại time-slot 25: 0
# Chi phí lưu trữ tại time-slot 25: 29235.038999999535
# Chi phí khởi tạo tại time-slot 25: 7301.544612794598
#
# --- Time-slot 26 ---
# Chi phí truyền thông tại time-slot 26: 0
# Chi phí lưu trữ tại time-slot 26: 29307.098999999558
# Chi phí khởi tạo tại time-slot 26: 7349.102693602673
#
# --- Time-slot 27 ---
# Chi phí truyền thông tại time-slot 27: 0
# Chi phí lưu trữ tại time-slot 27: 29533.394999999557
# Chi phí khởi tạo tại time-slot 27: 6623.021043771033
#
# --- Time-slot 28 ---
# Chi phí truyền thông tại time-slot 28: 0
# Chi phí lưu trữ tại time-slot 28: 29649.749999999396
# Chi phí khởi tạo tại time-slot 28: 6765.668350168341
#
# --- Time-slot 29 ---
# Chi phí truyền thông tại time-slot 29: 0
# Chi phí lưu trữ tại time-slot 29: 29800.634999999445
# Chi phí khởi tạo tại time-slot 29: 7469.056397306396
#
# --- Time-slot 30 ---
# Chi phí truyền thông tại time-slot 30: 0
# Chi phí lưu trữ tại time-slot 30: 29876.06999999947
# Chi phí khởi tạo tại time-slot 30: 8461.052188552172
#
# --- Time-slot 31 ---
# Chi phí truyền thông tại time-slot 31: 0
# Chi phí lưu trữ tại time-slot 31: 30013.7219999994
# Chi phí khởi tạo tại time-slot 31: 7923.010101010059
#
# --- Time-slot 32 ---
# Chi phí truyền thông tại time-slot 32: 0
# Chi phí lưu trữ tại time-slot 32: 30074.159999999596
# Chi phí khởi tạo tại time-slot 32: 7918.754208754175
#
# --- Time-slot 33 ---
# Chi phí truyền thông tại time-slot 33: 0
# Chi phí lưu trữ tại time-slot 33: 30405.686999999478
# Chi phí khởi tạo tại time-slot 33: 5593.823232323232
#
# --- Time-slot 34 ---
# Chi phí truyền thông tại time-slot 34: 0
# Chi phí lưu trữ tại time-slot 34: 30525.509999999616
# Chi phí khởi tạo tại time-slot 34: 5919.458754208739
#
# --- Time-slot 35 ---
# Chi phí truyền thông tại time-slot 35: 0
# Chi phí lưu trữ tại time-slot 35: 30682.127999999375
# Chi phí khởi tạo tại time-slot 35: 5793.581649831648
#
# --- Time-slot 36 ---
# Chi phí truyền thông tại time-slot 36: 0
# Chi phí lưu trữ tại time-slot 36: 30794.870999999363
# Chi phí khởi tạo tại time-slot 36: 6580.8989898989885
#
# --- Time-slot 37 ---
# Chi phí truyền thông tại time-slot 37: 0
# Chi phí lưu trữ tại time-slot 37: 30945.545999999384
# Chi phí khởi tạo tại time-slot 37: 5868.25420875421
#
# --- Time-slot 38 ---
# Chi phí truyền thông tại time-slot 38: 0
# Chi phí lưu trữ tại time-slot 38: 31043.24399999947
# Chi phí khởi tạo tại time-slot 38: 5846.737373737353
#
# --- Time-slot 39 ---
# Chi phí truyền thông tại time-slot 39: 0
# Chi phí lưu trữ tại time-slot 39: 31216.064999999293
# Chi phí khởi tạo tại time-slot 39: 6298.950336700324
#
# --- Time-slot 40 ---
# Chi phí truyền thông tại time-slot 40: 0
# Chi phí lưu trữ tại time-slot 40: 31231.079999999445
# Chi phí khởi tạo tại time-slot 40: 7336.108585858585
#
# --- Time-slot 41 ---
# Chi phí truyền thông tại time-slot 41: 0
# Chi phí lưu trữ tại time-slot 41: 31363.32899999955
# Chi phí khởi tạo tại time-slot 41: 7521.095117845102
#
# --- Time-slot 42 ---
# Chi phí truyền thông tại time-slot 42: 0
# Chi phí lưu trữ tại time-slot 42: 31490.396999999728
# Chi phí khởi tạo tại time-slot 42: 6948.649831649816
#
# --- Time-slot 43 ---
# Chi phí truyền thông tại time-slot 43: 0
# Chi phí lưu trữ tại time-slot 43: 31657.655999999475
# Chi phí khởi tạo tại time-slot 43: 6443.009259259233
#
# --- Time-slot 44 ---
# Chi phí truyền thông tại time-slot 44: 0
# Chi phí lưu trữ tại time-slot 44: 31786.85699999963
# Chi phí khởi tạo tại time-slot 44: 5805.631313131316
#
# --- Time-slot 45 ---
# Chi phí truyền thông tại time-slot 45: 0
# Chi phí lưu trữ tại time-slot 45: 31860.66299999948
# Chi phí khởi tạo tại time-slot 45: 5893.56397306397
#
# --- Time-slot 46 ---
# Chi phí truyền thông tại time-slot 46: 0
# Chi phí lưu trữ tại time-slot 46: 31993.68599999935
# Chi phí khởi tạo tại time-slot 46: 5545.680976430971
#
# --- Time-slot 47 ---
# Chi phí truyền thông tại time-slot 47: 0
# Chi phí lưu trữ tại time-slot 47: 32115.476999999657
# Chi phí khởi tạo tại time-slot 47: 5021.922558922554
#
# --- Time-slot 48 ---
# Chi phí truyền thông tại time-slot 48: 0
# Chi phí lưu trữ tại time-slot 48: 32141.18099999946
# Chi phí khởi tạo tại time-slot 48: 6325.642255892253
#
# --- Time-slot 49 ---
# Chi phí truyền thông tại time-slot 49: 0
# Chi phí lưu trữ tại time-slot 49: 32280.113999999605
# Chi phí khởi tạo tại time-slot 49: 6406.59511784512
#
# --- Time-slot 50 ---
# Chi phí truyền thông tại time-slot 50: 0
# Chi phí lưu trữ tại time-slot 50: 32316.032999999705
# Chi phí khởi tạo tại time-slot 50: 7638.057239057223
#
# --- Time-slot 51 ---
# Chi phí truyền thông tại time-slot 51: 0
# Chi phí lưu trữ tại time-slot 51: 32405.81399999968
# Chi phí khởi tạo tại time-slot 51: 6829.61868686867
#
# --- Time-slot 52 ---
# Chi phí truyền thông tại time-slot 52: 0
# Chi phí lưu trữ tại time-slot 52: 32535.671999999497
# Chi phí khởi tạo tại time-slot 52: 6533.995791245792
#
# --- Time-slot 53 ---
# Chi phí truyền thông tại time-slot 53: 0
# Chi phí lưu trữ tại time-slot 53: 32611.472999999627
# Chi phí khởi tạo tại time-slot 53: 7328.465488215465
#
# --- Time-slot 54 ---
# Chi phí truyền thông tại time-slot 54: 0
# Chi phí lưu trữ tại time-slot 54: 32667.464999999702
# Chi phí khởi tạo tại time-slot 54: 6485.376262626234
#
# --- Time-slot 55 ---
# Chi phí truyền thông tại time-slot 55: 0
# Chi phí lưu trữ tại time-slot 55: 32769.362999999794
# Chi phí khởi tạo tại time-slot 55: 7001.595959595931
#
# --- Time-slot 56 ---
# Chi phí truyền thông tại time-slot 56: 0
# Chi phí lưu trữ tại time-slot 56: 32775.302999999745
# Chi phí khởi tạo tại time-slot 56: 7359.613636363621
#
# --- Time-slot 57 ---
# Chi phí truyền thông tại time-slot 57: 0
# Chi phí lưu trữ tại time-slot 57: 32875.55999999986
# Chi phí khởi tạo tại time-slot 57: 6613.009259259247
#
# --- Time-slot 58 ---
# Chi phí truyền thông tại time-slot 58: 0
# Chi phí lưu trữ tại time-slot 58: 32960.88
# Chi phí khởi tạo tại time-slot 58: 6840.797138047114
#
# --- Time-slot 59 ---
# Chi phí truyền thông tại time-slot 59: 0
# Chi phí lưu trữ tại time-slot 59: 33101.19599999969
# Chi phí khởi tạo tại time-slot 59: 6041.156565656551
#
# --- Time-slot 60 ---
# Chi phí truyền thông tại time-slot 60: 0
# Chi phí lưu trữ tại time-slot 60: 33134.74199999987
# Chi phí khởi tạo tại time-slot 60: 6572.6986531986395
#
# --- Time-slot 61 ---
# Chi phí truyền thông tại time-slot 61: 0
# Chi phí lưu trữ tại time-slot 61: 33128.00699999967
# Chi phí khởi tạo tại time-slot 61: 7116.041245791228
#
# --- Time-slot 62 ---
# Chi phí truyền thông tại time-slot 62: 0
# Chi phí lưu trữ tại time-slot 62: 33311.28299999961
# Chi phí khởi tạo tại time-slot 62: 6469.684343434334
#
# --- Time-slot 63 ---
# Chi phí truyền thông tại time-slot 63: 0
# Chi phí lưu trữ tại time-slot 63: 33346.03799999955
# Chi phí khởi tạo tại time-slot 63: 7195.888047138024
#
# --- Time-slot 64 ---
# Chi phí truyền thông tại time-slot 64: 0
# Chi phí lưu trữ tại time-slot 64: 33371.01299999958
# Chi phí khởi tạo tại time-slot 64: 7329.681818181795
#
# --- Time-slot 65 ---
# Chi phí truyền thông tại time-slot 65: 0
# Chi phí lưu trữ tại time-slot 65: 33546.2459999995
# Chi phí khởi tạo tại time-slot 65: 6483.180976430966
#
# --- Time-slot 66 ---
# Chi phí truyền thông tại time-slot 66: 0
# Chi phí lưu trữ tại time-slot 66: 33574.79099999929
# Chi phí khởi tạo tại time-slot 66: 7023.919191919181
#
# --- Time-slot 67 ---
# Chi phí truyền thông tại time-slot 67: 0
# Chi phí lưu trữ tại time-slot 67: 33642.51299999964
# Chi phí khởi tạo tại time-slot 67: 6383.317340067332
#
# --- Time-slot 68 ---
# Chi phí truyền thông tại time-slot 68: 0
# Chi phí lưu trữ tại time-slot 68: 33757.59899999931
# Chi phí khởi tạo tại time-slot 68: 6467.8493265993075
#
# --- Time-slot 69 ---
# Chi phí truyền thông tại time-slot 69: 0
# Chi phí lưu trữ tại time-slot 69: 33867.54599999948
# Chi phí khởi tạo tại time-slot 69: 6211.660774410764
#
# --- Time-slot 70 ---
# Chi phí truyền thông tại time-slot 70: 0
# Chi phí lưu trữ tại time-slot 70: 33893.72999999962
# Chi phí khởi tạo tại time-slot 70: 6582.978956228949
#
# --- Time-slot 71 ---
# Chi phí truyền thông tại time-slot 71: 0
# Chi phí lưu trữ tại time-slot 71: 33958.715999999666
# Chi phí khởi tạo tại time-slot 71: 6178.98484848484
#
# --- Time-slot 72 ---
# Chi phí truyền thông tại time-slot 72: 0
# Chi phí lưu trữ tại time-slot 72: 33984.293999999856
# Chi phí khởi tạo tại time-slot 72: 6400.391414141411
#
# --- Time-slot 73 ---
# Chi phí truyền thông tại time-slot 73: 0
# Chi phí lưu trữ tại time-slot 73: 33992.6729999997
# Chi phí khởi tạo tại time-slot 73: 6627.1843434343555
#
# --- Time-slot 74 ---
# Chi phí truyền thông tại time-slot 74: 0
# Chi phí lưu trữ tại time-slot 74: 34053.04799999969
# Chi phí khởi tạo tại time-slot 74: 6127.077441077436
#
# --- Time-slot 75 ---
# Chi phí truyền thông tại time-slot 75: 0
# Chi phí lưu trữ tại time-slot 75: 34134.986999999644
# Chi phí khởi tạo tại time-slot 75: 6089.974747474749
#
# --- Time-slot 76 ---
# Chi phí truyền thông tại time-slot 76: 0
# Chi phí lưu trữ tại time-slot 76: 34217.423999999926
# Chi phí khởi tạo tại time-slot 76: 6269.001683501674
#
# --- Time-slot 77 ---
# Chi phí truyền thông tại time-slot 77: 0
# Chi phí lưu trữ tại time-slot 77: 34279.72199999969
# Chi phí khởi tạo tại time-slot 77: 6099.153198653174
#
# --- Time-slot 78 ---
# Chi phí truyền thông tại time-slot 78: 0
# Chi phí lưu trữ tại time-slot 78: 34248.5910000002
# Chi phí khởi tạo tại time-slot 78: 6975.569023568997
#
# --- Time-slot 79 ---
# Chi phí truyền thông tại time-slot 79: 0
# Chi phí lưu trữ tại time-slot 79: 34361.53799999984
# Chi phí khởi tạo tại time-slot 79: 6409.476430976405
#
# --- Time-slot 80 ---
# Chi phí truyền thông tại time-slot 80: 0
# Chi phí lưu trữ tại time-slot 80: 34421.22300000011
# Chi phí khởi tạo tại time-slot 80: 6076.276936026915
#
# --- Time-slot 81 ---
# Chi phí truyền thông tại time-slot 81: 0
# Chi phí lưu trữ tại time-slot 81: 34382.687999999966
# Chi phí khởi tạo tại time-slot 81: 7194.853535353523
#
# --- Time-slot 82 ---
# Chi phí truyền thông tại time-slot 82: 0
# Chi phí lưu trữ tại time-slot 82: 34520.646000000015
# Chi phí khởi tạo tại time-slot 82: 6137.4696969697
#
# --- Time-slot 83 ---
# Chi phí truyền thông tại time-slot 83: 0
# Chi phí lưu trữ tại time-slot 83: 34499.597999999736
# Chi phí khởi tạo tại time-slot 83: 6082.392255892249
#
# --- Time-slot 84 ---
# Chi phí truyền thông tại time-slot 84: 0
# Chi phí lưu trữ tại time-slot 84: 34577.0759999998
# Chi phí khởi tạo tại time-slot 84: 6160.54882154882
#
# --- Time-slot 85 ---
# Chi phí truyền thông tại time-slot 85: 0
# Chi phí lưu trữ tại time-slot 85: 34693.16700000001
# Chi phí khởi tạo tại time-slot 85: 4926.4385521885415
#
# --- Time-slot 86 ---
# Chi phí truyền thông tại time-slot 86: 0
# Chi phí lưu trữ tại time-slot 86: 34694.55599999988
# Chi phí khởi tạo tại time-slot 86: 6030.517676767678
#
# --- Time-slot 87 ---
# Chi phí truyền thông tại time-slot 87: 0
# Chi phí lưu trữ tại time-slot 87: 34672.836000000105
# Chi phí khởi tạo tại time-slot 87: 6549.773569023554
#
# --- Time-slot 88 ---
# Chi phí truyền thông tại time-slot 88: 0
# Chi phí lưu trữ tại time-slot 88: 34836.63899999991
# Chi phí khởi tạo tại time-slot 88: 5484.989057239057
#
# --- Time-slot 89 ---
# Chi phí truyền thông tại time-slot 89: 0
# Chi phí lưu trữ tại time-slot 89: 34843.35900000006
# Chi phí khởi tạo tại time-slot 89: 5936.363636363615
#
# --- Time-slot 90 ---
# Chi phí truyền thông tại time-slot 90: 0
# Chi phí lưu trữ tại time-slot 90: 34868.54100000032
# Chi phí khởi tạo tại time-slot 90: 5641.855218855226
#
# --- Time-slot 91 ---
# Chi phí truyền thông tại time-slot 91: 0
# Chi phí lưu trữ tại time-slot 91: 34890.489000000234
# Chi phí khởi tạo tại time-slot 91: 6337.414983164977
#
# --- Time-slot 92 ---
# Chi phí truyền thông tại time-slot 92: 0
# Chi phí lưu trữ tại time-slot 92: 34978.88699999987
# Chi phí khởi tạo tại time-slot 92: 5507.721380471373
#
# --- Time-slot 93 ---
# Chi phí truyền thông tại time-slot 93: 0
# Chi phí lưu trữ tại time-slot 93: 34977.15599999992
# Chi phí khởi tạo tại time-slot 93: 5569.5606060606
#
# --- Time-slot 94 ---
# Chi phí truyền thông tại time-slot 94: 0
# Chi phí lưu trữ tại time-slot 94: 35085.19199999982
# Chi phí khởi tạo tại time-slot 94: 5354.867003366986
#
# --- Time-slot 95 ---
# Chi phí truyền thông tại time-slot 95: 0
# Chi phí lưu trữ tại time-slot 95: 35056.80899999986
# Chi phí khởi tạo tại time-slot 95: 6908.734006733994
#
# --- Time-slot 96 ---
# Chi phí truyền thông tại time-slot 96: 0
# Chi phí lưu trữ tại time-slot 96: 35112.01499999988
# Chi phí khởi tạo tại time-slot 96: 6352.320707070701
#
# --- Time-slot 97 ---
# Chi phí truyền thông tại time-slot 97: 0
# Chi phí lưu trữ tại time-slot 97: 35238.707999999955
# Chi phí khởi tạo tại time-slot 97: 5280.288720538704
#
# --- Time-slot 98 ---
# Chi phí truyền thông tại time-slot 98: 0
# Chi phí lưu trữ tại time-slot 98: 35153.750999999946
# Chi phí khởi tạo tại time-slot 98: 7188.010942760916
#
# --- Time-slot 99 ---
